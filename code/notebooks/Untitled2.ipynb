# %%
import pandas as pd

# %%
df=pd.read_excel('./phase1results_new/dsmsorted.xlsx')
df
# Out:
#        Unnamed: 0  bio1_vs_all  bio2_vs_all  bio5_vs_all
# 0         madrs_4     0.016220     0.017123     0.031588
# 1     sfs_retotal     0.024523     0.023839     0.025915
# 2        panss_p4     0.023220     0.011422     0.025823
# 3        panss_p1     0.017615     0.025579     0.025590
# 4       panss_g13     0.014316     0.019318     0.025056
# 5        panss_g2     0.019203     0.018820     0.024966
# 6       panss_g10     0.014940     0.016861     0.023791
# 7        panss_g1     0.028547     0.020018     0.023233
# 8        young_11     0.014539     0.016995     0.023002
# 9         young_5     0.020342     0.018379     0.021701
# 10       panss_n4     0.019826     0.015304     0.021456
# 11        madrs_9     0.023037     0.014510     0.021454
# 12       panss_n6     0.015650     0.014019     0.021425
# 13  sfs_ipcptotal     0.025126     0.025201     0.020568
# 14  sfs_ipcctotal     0.022381     0.017508     0.020343
# ...

# %%
a=(1875 + 96*60)
a
# Out:
# 7635

# %%
a*7
# Out:
# 53445

# %%
96*7
# Out:
# 672

# %%
1875*7
# Out:
# 13125

# %%
96*60*7
# Out:
# 40320
