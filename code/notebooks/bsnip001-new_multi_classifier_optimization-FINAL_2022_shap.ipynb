# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from scipy.spatial import ConvexHull
from tqdm import tqdm
import random
plt.style.use('ggplot')
import pickle
from sklearn import tree
from sklearn.tree import export_graphviz
from joblib import dump, load
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
# %matplotlib inline
from sklearn.impute import SimpleImputer
from scipy import interpolate
from scipy.interpolate import interp1d

# %%
MAX_DEPTH=6
NUMESTIMATORS=2

# %%
xf=pd.read_csv('./2022summer/adeptphase2/Cognition.csv',index_col=0)
xf.index.name='subject_id'
df=pd.read_csv('combined_bsnip.csv',index_col=0).drop('DSM',axis=1)
#df=df.join(xf)#.head()
#df=df.join(Ef_.set_index('Subid'))

DELVAR=['project','BACS_COMP_Z']
cols=[x for x in df.columns if x not in DELVAR]
df=df[cols]

# %%
#DELVAR=['project']#,'BACS_COMP_Z']
#cols=[x for x in df.columns if x not in DELVAR]
#df=df[cols]

# %%
#df=pd.read_csv('combined_bsnip.csv',index_col=0).drop('DSM',axis=1)
#df=df.drop('project',axis=1)
#df=df.drop('BACS_COMP_Z_within',axis=1)
#df.head()

# %%
feature_names=df.columns
feature_names=feature_names[1:]
feature_names
# Out:
# Index(['panss_p1', 'panss_p2', 'panss_p3', 'panss_p4', 'panss_p5', 'panss_p6',
#        'panss_p7', 'panss_n1', 'panss_n2', 'panss_n3', 'panss_n4', 'panss_n5',
#        'panss_n6', 'panss_n7', 'panss_g1', 'panss_g2', 'panss_g3', 'panss_g4',
#        'panss_g5', 'panss_g6', 'panss_g7', 'panss_g8', 'panss_g9', 'panss_g10',
#        'panss_g11', 'panss_g12', 'panss_g13', 'panss_g14', 'panss_g15',
#        'panss_g16', 'madrs_1', 'madrs_2', 'madrs_3', 'madrs_4', 'madrs_5',
#        'madrs_6', 'madrs_7', 'madrs_8', 'madrs_9', 'madrs_10', 'young_1',
#        'young_2', 'young_3', 'young_4', 'young_5', 'young_6', 'young_7',
#        'young_8', 'young_9', 'young_10', 'young_11', 'sfs_setotal',
#        'sfs_ictotal', 'sfs_ipcptotal', 'sfs_ipcctotal', 'sfs_retotal',
#        'sfs_prototal', 'sfs_oetotal'],
#       dtype='object')

# %%
#df=df[df['Biotype']==3]
df=df.dropna()
df0=df
[p1,p2,p3]=(df0.Biotype.value_counts()/df0.Biotype.value_counts().sum()).values

# %%
df.Biotype.value_counts()
# 3 is HC
# Out:
# 3    534
# 1    517
# 2    506
# Name: Biotype, dtype: int64

# %%
# load model
import dill
with open('/home/ishanu/P1models//P1_7_3_0.mod','rb') as f:
    M=dill.load(f)
# Out:
# /home/ishanu/.local/lib/python3.10/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator ExtraTreeClassifier from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/ishanu/.local/lib/python3.10/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator ExtraTreesClassifier from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
M.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
import shap
clfA=M[2]['estimator']
clfB=M[3]['estimator']
clfC=M[1]['estimator']

# %%
th1=M[2]['rocs'][list(M[2]['rocs'].keys())[0]]['thresholds'][1]#['thresholds']
th2=M[3]['rocs'][list(M[3]['rocs'].keys())[0]]['thresholds'][1]#['thresholds']
print(th1,th2)
# Out:
# 0.6020122531511962 0.6387764301164403

# %%
def prob_(x):
    a=clfA.predict_proba(x.reshape(1, -1))
    b=clfB.predict_proba(x.reshape(1, -1))
    #print(a)
    if a[0][0] > th1:
        d=2
    else:
        if b[0][0] > th2:
            d=3
        else:
            d=1
    return d

# %%
def prob__(X):
    return 1+(clfA.predict_proba(X)[:,0]>th1)*1+(clfB.predict_proba(X)[:,0]>th2)*2

# %%
df=df0
X=df.drop('Biotype',axis=1).values
y=df.Biotype.values#.astype(str)
y=[(int(x)==2)+0 for x in y ]

# %%
explainerX = shap.Explainer(prob__,X)
shap_valuesX=explainerX(df.drop('Biotype',axis=1))
# Out:
# Permutation explainer: 1558it [01:06, 20.66it/s]

# %%
shap.plots.bar(shap_valuesX, show=False)
plt.title('End to end SHAP values')
plt.savefig('./phase1results_new/shapXP1.png',dpi=300,bbox_inches='tight',transparent=True)

# %%
explainer = shap.Explainer(clfA.predict,X)
shap_values=explainer(df.drop('Biotype',axis=1))
# Out:
# Permutation explainer: 1558it [00:30, 33.75it/s]

# %%
shap.plots.bar(shap_values,show=False)
plt.title('SHAP for B2')
plt.savefig('./phase1results_new/shap2P1.png',dpi=300,bbox_inches='tight',transparent=True)

# %%
df=df0
X=df.drop('Biotype',axis=1).values
y=df.Biotype.values#.astype(str)
y=[(int(x)==3)+0 for x in y ]

# %%
explainerb = shap.Explainer(clfB.predict,X)
shap_valuesb=explainerb(df.drop('Biotype',axis=1))
# Out:
# Permutation explainer: 1558it [00:30, 33.22it/s]

# %%
shap.plots.bar(shap_valuesb,show=False)
plt.title('SHAP for B3')

plt.savefig('./phase1results_new/shap3P1.png',dpi=300,bbox_inches='tight',transparent=True)

# %%
df=df0
X=df.drop('Biotype',axis=1).values
y=df.Biotype.values#.astype(str)
y=[(int(x)==1)+0 for x in y ]

# %%
explainerC = shap.Explainer(clfC.predict,X)
shap_valuesC=explainerC(df.drop('Biotype',axis=1))
shap.plots.bar(shap_valuesC,show=False)
plt.title('SHAP for B1')

plt.savefig('./phase1results_new/shap1P1.png',dpi=300,bbox_inches='tight',transparent=True)
# Out:
# Permutation explainer: 1558it [00:30, 33.85it/s]
