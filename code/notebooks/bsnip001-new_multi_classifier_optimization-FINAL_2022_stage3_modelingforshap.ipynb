# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from scipy.spatial import ConvexHull
from tqdm import tqdm
import random
plt.style.use('ggplot')
import pickle
from sklearn import tree
from sklearn.tree import export_graphviz
from joblib import dump, load
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
# %matplotlib inline
from sklearn.impute import SimpleImputer
from scipy import interpolate
from scipy.interpolate import interp1d

# %%
MAX_DEPTH=6
NUMESTIMATORS=2

# %%
Ef=pd.read_excel('./2022summer/adeptphase3/BIOTYPES_HC_withBiofactors_21_1008.xlsx')
Ef.columns

Ef_=Ef[['Subid',#'Age', 'Sex',
       'EEG1', 'EEG2', 'EEG3', 'EEG4', 'EEG5', 'EEG6', 'LATENCY',
       'ANTISACCADE', 'BACS', 'SST', 'IEA']]

xf=pd.read_csv('./2022summer/adeptphase2/Cognition.csv',index_col=0)
xf.index.name='subject_id'
df=pd.read_csv('combined_bsnip.csv',index_col=0).drop('DSM',axis=1)
df=df.join(xf)#.head()
df=df.join(Ef_.set_index('Subid'))

DELVAR=['project']#,'Age','Sex','BSNIP1VS2','Psychosis','BACS_COMP_Z','LATENCY','SST','BACS','ANTISACCADE']
cols=[x for x in df.columns if x not in DELVAR]
df=df[cols]

# %%
Ef['DSM String'].value_counts()
# Out:
# HC      895
# SZP     781
# SADP    581
# BPP     541
# Name: DSM String, dtype: int64

# %%
def getAuc(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,FPR=[],TPR=[],VERBOSE=False, USE_ONLY=None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit,class_weight='balanced'),
                RandomForestClassifier(n_estimators=n_estimators,
                                       max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                ExtraTreesClassifier(n_estimators=n_estimators,
                                     max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict_proba(X_test)
        #print(X_test,y_pred)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        auc=metrics.auc(fpr, tpr)
        if VERBOSE:
            print(auc)

        FPR=np.append(FPR,fpr)
        TPR=np.append(TPR,tpr)
    points=np.array([[a[0],a[1]] for a in zip(FPR,TPR)])
    hull = ConvexHull(points)
    x=np.argsort(points[hull.vertices,:][:,0])
    auc=metrics.auc(points[hull.vertices,:][x,0],points[hull.vertices,:][x,1])
    return auc,CLASSIFIERS


def saveFIG(filename='tmp.pdf',AXIS=False):
    '''
        save fig for publication
    '''
    import pylab as plt
    plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
    plt.margins(0,0)
    if not AXIS:
        plt.gca().xaxis.set_major_locator(plt.NullLocator())
        plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig(filename,dpi=300, bbox_inches = 'tight',
                pad_inches = 0,transparent=False) 
    return

# %%
def getacc(c1,c2,p1,p2,p3,f1,f2):
    s1=f1(1-c1)
    s2=f2(1-c2)
    A=(c1*c2*(1-p1)*(1-p2))/((c1*(1-p1)+(1-s1)*p1)*(c2*(1-p2)+(1-s2)*p2))
    B=(1-s1)*p1 - (1-c1)*(1-p1) + (1-s2)*p2 - (1-c2)*(1-p2) + p3
    return s1*p1+s2*p2+ A*B

# %%
def getCoverage(model,verbose=True):
    '''
        return how many distinct items (questions)
        are used in the model set.
        This includes the set of questions being
        covered by all forms that may be 
        generated by the model set
    '''
    FS=[]
    for m in model:
        for count in range(len(m.estimators_)):
            clf=m.estimators_[count]
            fs=clf.tree_.feature[clf.tree_.feature>0]
            FS=np.array(list(set(np.append(FS,fs))))
    if verbose:
        print("Number of items used: ", FS.size)
    return FS

def getConfusion(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,CONFUSION={},VERBOSE=False, USE_ONLY=None,target_names = None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit),
                RandomForestClassifier(n_estimators=n_estimators,class_weight='balanced',
                                       max_depth=max_depth,min_samples_split=minsplit),
                ExtraTreesClassifier(n_estimators=n_estimators,class_weight='balanced',
                                     max_depth=max_depth,min_samples_split=minsplit),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict(X_test)
        print(y_test,y_pred)
        cmat=confusion_matrix(y_test, y_pred)
        acc=accuracy_score(y_test, y_pred)
        
        CONFUSION[clf]=cmat
        
        if VERBOSE:
            print(classification_report(y_test, y_pred, target_names=target_names))
            print('Confusion MAtrix:\n', cmat)
            print(' ')
            print('Accuracy:', acc)

        
    return CONFUSION,acc,y_test,y_pred

# %%
def getFmap(CLFstar,X,y):
    auc_=[]
    ROC={}
    fpr_ = np.linspace(0, 1, num=20, endpoint=True)
    for run in np.arange(1000):
        clf=CLFstar
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
        y_pred=clf.predict_proba(X_test)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        f = interp1d(fpr, tpr)
        th = interp1d(fpr, thresholds)
        auc_=np.append(auc_,metrics.auc(fpr_, f(fpr_)))
        ROC[metrics.auc(fpr, tpr)]={'fpr':fpr_,'tpr':f(fpr_),'thresholds':th(fpr_)}

    TPR=[]
    for a in ROC.keys():
        TPR=np.append(TPR,ROC[a]['tpr'])
    TPR=TPR.reshape(int(len(TPR)/len(fpr_)),len(fpr_))
    medTPR=np.median(TPR,axis=0)
    return interpolate.interp1d(fpr_,np.median(TPR,axis=0) ), ROC

# %%
#df=df[df['Biotype']==3]
df=df.dropna()
df0=df
[p1,p2,p3]=(df0.Biotype.value_counts()/df0.Biotype.value_counts().sum()).values

# %%
df.Biotype.value_counts()
# 3 is HC
# Out:
# 3    334
# 1    293
# 2    254
# Name: Biotype, dtype: int64

# %%
def getRES(df0,MAX_DEPTH=6,NUMESTIMATORS=2,MODELfile='model123eegshap.mod'):
    df=df0
    X=df.iloc[:,1:].values
    y=df.Biotype.values#.astype(str)
    y=[(int(x)==1)+0 for x in y ]

    MODEL={}
    
    ACC=[]
    CLFh={}
    for run in np.arange(500):
        auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
                   minsplit=2,VERBOSE=False, USE_ONLY=[2])
        ACC=np.append(ACC,auc)
        if auc > 0.5:
            CLFh[auc]=CLFS
    CLFstar1=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
    f0,ROC0=getFmap(CLFstar1,X,y)
    
    MODEL[1]={'estimator':CLFstar1,'fmap':f0,'rocs':ROC0}
    
    df=df0
    X=df.iloc[:,1:].values
    y=df.Biotype.values#.astype(str)
    y=[(int(x)==2)+0 for x in y ]

    
    ACC=[]
    CLFh={}
    for run in np.arange(500):
        auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
                   minsplit=2,VERBOSE=False, USE_ONLY=[2])
        ACC=np.append(ACC,auc)
        if auc > 0.5:
            CLFh[auc]=CLFS
    CLFstarA=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
    f1,ROCA=getFmap(CLFstarA,X,y)
    
    MODEL[2]={'estimator':CLFstarA,'fmap':f1,'rocs':ROCA}

    #df=df0[df0.Biotype.isin([1,5])]
    df=df0
    X=df.iloc[:,1:].values
    y=df.Biotype.values#.astype(str)
    y=[(int(x)==3)+0 for x in y ]

    ACC=[]
    CLFh={}
    for run in np.arange(500):
        auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
                   minsplit=2,VERBOSE=False, USE_ONLY=[2])
        ACC=np.append(ACC,auc)
        if auc > 0.5:
            CLFh[auc]=CLFS
    CLFstarB=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
    f2,ROCB=getFmap(CLFstarB,X,y)
    MODEL[3]={'estimator':CLFstarB,'fmap':f2,'rocs':ROCB}

    R=[]
    for i in np.arange(.7,.99,.01):
        for j in np.arange(.7,.99,.01):
            R=np.append(R,[i,j,getacc(i,j,p1,p2,p3,f1,f2)])
    R=pd.DataFrame(R.reshape(len(R)//3,3))
    R.columns=['c1','c2','acc']
    R['s1']=f1(1-R.c1)
    R['s2']=f2(1-R.c2)


    X_test=df.values.astype(np.float32)
    L=[]

    for sample_id in np.arange(len(X_test)):
        Node_index=[]
        for i in CLFstarA.estimators_:
            threshold= i.tree_.threshold
            feature= i.tree_.feature
            node_indicator = i.tree_.decision_path(X_test)
            leaf_id = i.tree_.apply(X_test)

            node_index = node_indicator.indices[
            node_indicator.indptr[sample_id] : node_indicator.indptr[sample_id + 1]]
            Node_index=np.append(Node_index,node_index)

        for i in CLFstarB.estimators_:
            threshold= i.tree_.threshold
            feature= i.tree_.feature
            node_indicator = i.tree_.decision_path(X_test)
            leaf_id = i.tree_.apply(X_test)

            node_index = node_indicator.indices[
            node_indicator.indptr[sample_id] : node_indicator.indptr[sample_id + 1]]
            Node_index=np.append(Node_index,node_index)
        L=np.append(L,len(set(Node_index))-2)
    L=np.array(L)
    #print(np.mean(L),np.median(L))
    #sns.displot(L);


    RES=R.sort_values('acc',ascending=False).head(1)
    RES['nq_mean']=np.mean(L)
    RES['nq_median']=np.median(L)
    
    import dill
    with open(MODELfile, "wb") as dill_file:
        dill.dump(MODEL, dill_file)
    #dill_file.close()
    
    return RES, ROCA, ROCB, CLFstarA, CLFstarB

# %%
for i in tqdm(np.arange(10)):
    Rs,ROCa,ROCb,CLFstarA,CLFstarB=getRES(df0,MAX_DEPTH=10,MODELfile='model123eeg.mod_'+str(i))
    #Rs
# Out:
# 100%|███████████████████████████████████████████| 10/10 [03:31<00:00, 21.12s/it]

# %%
! ls -lhtr
# Out:
# total 125M
# -rw-rw-r--. 1 ishanu ishanu  15K Nov 16 12:31  3IMPFRACsczVscaff_2_.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.3K Nov 16 12:31  3_X2X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  15K Nov 16 12:31  3IMPFRACsczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu  408 Nov 16 12:31  3_4_tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 1.6K Nov 16 12:31  3_4_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu  384 Nov 16 12:31  3_2__tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 956K Nov 16 12:31  3_X2X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 795K Nov 16 12:31  3_X2X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 1.5K Nov 16 12:31  3_X4X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu 962K Nov 16 12:31  3_X4X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 851K Nov 16 12:31  3_X4X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 4.8M Nov 16 12:31  3_XX2XX_PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 122K Nov 16 12:31  3sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.6K Nov 16 12:31  3_sczVscaff_2_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu 124K Nov 16 12:31  3sczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu 896K Nov 16 12:31  4PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu  15K Nov 16 12:31  6IMPFRACsczVscaff_2_.pdf
# -rw-rw-r--. 1 ishanu ishanu  15K Nov 16 12:31  6IMPFRACsczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu  384 Nov 16 12:31  6_2__tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 892K Nov 16 12:31  4PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 4.1K Nov 16 12:31  6_X2X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  410 Nov 16 12:31  6_4_tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 1.6K Nov 16 12:31  6_4_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu 2.9M Nov 16 12:31  6_X2X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 3.7K Nov 16 12:31  6_X4X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu 2.7M Nov 16 12:31  6_X2X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 2.8M Nov 16 12:31  6_X4X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 2.4M Nov 16 12:31  6_X4X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu  12M Nov 16 12:31  6_XX2XX_PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 103K Nov 16 12:31  6sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.6K Nov 16 12:31  6_sczVscaff_2_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu 123K Nov 16 12:31  6sczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu 8.0K Nov 16 12:31  9_X2X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  15K Nov 16 12:31  9IMPFRACsczVscaff_2_.pdf
# -rw-rw-r--. 1 ishanu ishanu  15K Nov 16 12:31  9IMPFRACsczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu  408 Nov 16 12:31  9_4_tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 1.6K Nov 16 12:31  9_4_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu  248 Nov 16 12:31  9_2__tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 4.8M Nov 16 12:31  9_X2X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 7.4K Nov 16 12:31  9_X4X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu 5.4M Nov 16 12:31  9_X2X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 4.7M Nov 16 12:31  9_X4X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 4.8M Nov 16 12:31  9_X4X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu  97K Nov 16 12:31  9sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.6K Nov 16 12:31  9_sczVscaff_2_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu 109K Nov 16 12:31  9sczsceff.pdf
# drwxrwxr-x. 5 ishanu ishanu 4.0K Nov 16 12:31  CAD-psych-paper
# -rw-rw-r--. 1 ishanu ishanu 2.4K Nov 16 12:31  CAD_.ipynb
# -rw-rw-r--. 1 ishanu ishanu 2.9K Nov 16 12:31  PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  28K Nov 16 12:31  PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 6.5K Nov 16 12:31  PSYmodel_2_3.pkl
# -rw-rw-r--. 1 ishanu ishanu 101K Nov 16 12:31  PSYCHO.DAT
# -rw-rw-r--. 1 ishanu ishanu 2.3M Nov 16 12:31  PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 1.8M Nov 16 12:31  PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 137K Nov 16 12:31  ROC.png
# -rw-rw-r--. 1 ishanu ishanu 187K Nov 16 12:31  ROC12vall_3vall_clinical_cognitive.png
# -rw-rw-r--. 1 ishanu ishanu  71K Nov 16 12:31  ROCsummer.png
# -rw-rw-r--. 1 ishanu ishanu 141K Nov 16 12:31  ROC2vall_3vall_clinical_cognitive.png
# -rw-rw-r--. 1 ishanu ishanu  25K Nov 16 12:31  ResultPSY32.pdf
# -rw-rw-r--. 1 ishanu ishanu  26K Nov 16 12:31  ResultPSY23.pdf
# -rw-rw-r--. 1 ishanu ishanu  26K Nov 16 12:31  Result32.pdf
# -rw-rw-r--. 1 ishanu ishanu  26K Nov 16 12:31  Result23.pdf
# drwxrwxr-x. 3 ishanu ishanu 4.0K Nov 16 12:31 'Untitled Folder'
# -rw-rw-r--. 1 ishanu ishanu 4.9M Nov 16 12:31  SCH+scffvxmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 2.6K Nov 16 12:31  Y.dat
# -rw-rw-r--. 1 ishanu ishanu  34K Nov 16 12:31  Y.csv
# -rw-rw-r--. 1 ishanu ishanu 5.0K Nov 16 12:31  Untitled.ipynb
# drwxrwxr-x. 2 ishanu ishanu 4.0K Nov 16 12:31  __pycache__
# -rw-rw-r--. 1 ishanu ishanu  56K Nov 16 12:31  accvsitemnumber.png
# -rw-rw-r--. 1 ishanu ishanu  60K Nov 16 12:31  accvsnum.png
# -rw-rw-r--. 1 ishanu ishanu  52K Nov 16 12:31  accvsitemnumber1.png
# -rw-rw-r--. 1 ishanu ishanu  69K Nov 16 12:31  accvsitemnumber1noBAC.png
# -rw-rw-r--. 1 ishanu ishanu 6.2K Nov 16 12:31  bck_1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 123K Nov 16 12:31  bck_0.ipynb
# -rw-rw-r--. 1 ishanu ishanu 235K Nov 16 12:31  bsnip.csv
# -rw-rw-r--. 1 ishanu ishanu 142K Nov 16 12:31  bsnip001-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 142K Nov 16 12:31  bsnip001-Copy1_new-b1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 138K Nov 16 12:31  bsnip001-Copy1_new-b3.ipynb
# -rw-rw-r--. 1 ishanu ishanu 137K Nov 16 12:31  bsnip001-Copy1_new-b2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 106K Nov 16 12:31  bsnip001-Copy2_new-B3.ipynb
# -rw-rw-r--. 1 ishanu ishanu  79K Nov 16 12:31  bsnip001-Copy2.ipynb
# -rw-rw-r--. 1 ishanu ishanu  73K Nov 16 12:31  bsnip001-Copy3_new.ipynb
# -rw-rw-r--. 1 ishanu ishanu  64K Nov 16 12:31  bsnip001-Copy3.ipynb
# -rw-rw-r--. 1 ishanu ishanu  26K Nov 16 12:31  bsnip001-Copy2_new_CF.ipynb
# -rw-rw-r--. 1 ishanu ishanu  92K Nov 16 12:31  bsnip001-Copy2_new_1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 216K Nov 16 12:31  bsnip001-new_multi_classifier_optimization-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 104K Nov 16 12:31  bsnip001-new_decision_tree_for_classifiers.ipynb
# -rw-rw-r--. 1 ishanu ishanu  47K Nov 16 12:31  bsnip001-impcalculation.ipynb
# -rw-rw-r--. 1 ishanu ishanu  48K Nov 16 12:31  bsnip001-final_stage2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 216K Nov 16 12:31  bsnip001-new_multi_classifier_optimization-Copy3.ipynb
# -rw-rw-r--. 1 ishanu ishanu 214K Nov 16 12:31  bsnip001-new_multi_classifier_optimization.ipynb
# -rw-rw-r--. 1 ishanu ishanu 106K Nov 16 12:31  bsnip001_L1.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Nov 16 12:31  bsnip001_L1_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu  99K Nov 16 12:31  bsnip001_L15.pdf
# -rw-rw-r--. 1 ishanu ishanu  79K Nov 16 12:31  bsnip001.ipynb
# -rw-rw-r--. 1 ishanu ishanu 101K Nov 16 12:31  bsnip001_L3.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Nov 16 12:31  bsnip001_L3_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu 103K Nov 16 12:31  bsnip001_L2.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Nov 16 12:31  bsnip001_L2_importances_.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Nov 16 12:31  bsnip001_L2_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu 110K Nov 16 12:31  bsnip001_updated_L2.pdf
# -rw-rw-r--. 1 ishanu ishanu 109K Nov 16 12:31  bsnip001_updated_L1.pdf
# -rw-rw-r--. 1 ishanu ishanu 102K Nov 16 12:31  bsnip001_L5.pdf
# -rw-rw-r--. 1 ishanu ishanu 113K Nov 16 12:31  bsnip001_updated_L3.pdf
# drwxrwxr-x. 4 ishanu ishanu 4.0K Nov 16 12:31  bsnipFIG
# -rw-rw-r--. 1 ishanu ishanu 9.1K Nov 16 12:31  ccx.py
# -rw-rw-r--. 1 ishanu ishanu 244K Nov 16 12:31  combined_bsnip.csv
# -rw-rw-r--. 1 ishanu ishanu 397K Nov 16 12:31  combinedBSNIP1_BSNIP2_PARDIP_clinical_011921.xlsx
# -rw-rw-r--. 1 ishanu ishanu  927 Nov 16 12:31  dummy23tree.dot
# -rw-rw-r--. 1 ishanu ishanu  85K Nov 16 12:31  download.png
# -rw-rw-r--. 1 ishanu ishanu 522K Nov 16 12:31  dummy23tree0.png
# -rw-rw-r--. 1 ishanu ishanu 529K Nov 16 12:31  dummy23tree1.png
# -rw-rw-r--. 1 ishanu ishanu 1.7K Nov 16 12:31  dummy32tree.dot
# -rw-rw-r--. 1 ishanu ishanu 524K Nov 16 12:31  dummy23tree2.png
# -rw-rw-r--. 1 ishanu ishanu 998K Nov 16 12:31  dummy32tree0.png
# -rw-rw-r--. 1 ishanu ishanu 1.7K Nov 16 12:31  dummytree.dot
# -rw-rw-r--. 1 ishanu ishanu 982K Nov 16 12:31  dummy32tree1.png
# -rw-rw-r--. 1 ishanu ishanu 982K Nov 16 12:31  dummytree0.png
# -rw-rw-r--. 1 ishanu ishanu 955K Nov 16 12:31  dummytree1.png
# -rw-rw-r--. 1 ishanu ishanu 5.5K Nov 16 12:31  imp.xls
# -rw-rw-r--. 1 ishanu ishanu 484K Nov 16 12:31  imp.png
# -rw-rw-r--. 1 ishanu ishanu 5.5K Nov 16 12:31  imp_noBACS.xls
# -rw-rw-r--. 1 ishanu ishanu 5.5K Nov 16 12:31  imp123.xls
# -rw-rw-r--. 1 ishanu ishanu 709K Nov 16 12:31  imp_small.png
# -rw-rw-r--. 1 ishanu ishanu 691K Nov 16 12:31  imp_small123.png
# -rw-rw-r--. 1 ishanu ishanu  63K Nov 16 12:31  impsummer.png
# -rw-rw-r--. 1 ishanu ishanu 649K Nov 16 12:31  imp_small_noBAC.png
# -rw-rw-r--. 1 ishanu ishanu  187 Nov 16 12:31  mean_cf.csv
# -rw-rw-r--. 1 ishanu ishanu 127K Nov 16 12:31  inferModel_.ipynb
# -rw-rw-r--. 1 ishanu ishanu 103K Nov 16 12:31  inferModel_-grantdummy.ipynb
# -rw-rw-r--. 1 ishanu ishanu 784K Nov 16 12:31  model123.mod
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_0
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_1
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_2
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_3
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_4
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_5
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_6
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_7
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_8
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  model123.mod_9
# -rw-rw-r--. 1 ishanu ishanu 800K Nov 16 12:31  model123a.mod
# -rw-rw-r--. 1 ishanu ishanu 9.3K Nov 16 12:31  model_2_3.pkl
# -rw-rw-r--. 1 ishanu ishanu 539K Nov 16 12:31  model23.mod
# -rw-rw-r--. 1 ishanu ishanu  53K Nov 16 12:31  model_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 3.1M Nov 16 12:31  movie_nncomput_combined.ipynb
# drwxrwxr-x. 3 ishanu ishanu 4.0K Nov 16 12:31  newcodes
# -rw-rw-r--. 1 ishanu ishanu  22K Nov 16 12:31  nitems_SSvO.csv
# -rw-rw-r--. 1 ishanu ishanu 135K Nov 16 12:31  psycho_orig1.ipynb
# -rw-rw-r--. 1 ishanu ishanu  25K Nov 16 12:31  psychoByDiag.csv
# -rw-rw-r--. 1 ishanu ishanu 1.4M Nov 16 12:31  psychosis-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 221K Nov 16 12:31  psychosis-Copy2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 231K Nov 16 12:31  psychosis-Copy2a.ipynb
# -rw-rw-r--. 1 ishanu ishanu 122K Nov 16 12:31  psychosis-Copy3.ipynb
# -rw-rw-r--. 1 ishanu ishanu 295K Nov 16 12:31  psychosis-Copy4.ipynb
# -rw-rw-r--. 1 ishanu ishanu 102K Nov 16 12:31  sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu  93K Nov 16 12:31  sczVSall.pdf
# -rw-rw-r--. 1 ishanu ishanu  571 Nov 16 12:31  roc_new.csv
# -rw-rw-r--. 1 ishanu ishanu  291 Nov 16 12:31  roc_.csv
# -rw-rw-r--. 1 ishanu ishanu  179 Nov 16 12:31  roc.csv
# -rw-rw-r--. 1 ishanu ishanu  460 Nov 16 12:31  rescbd.csv
# -rw-rw-r--. 1 ishanu ishanu 698K Nov 16 12:31  psychosis.ipynb
# -rw-rw-r--. 1 ishanu ishanu 120K Nov 16 12:31  sczVscaff_XX_PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 119K Nov 16 12:31  sczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu 117K Nov 16 12:31  sczsceffVS34_RAW.pdf
# -rw-rw-r--. 1 ishanu ishanu 117K Nov 16 12:31  sczsceffVS34_Q+RAW.pdf
# -rw-rw-r--. 1 ishanu ishanu 117K Nov 16 12:31  sczsceffVS34.pdf
# -rw-rw-r--. 1 ishanu ishanu 193K Nov 16 12:31  shap1.png
# -rw-rw-r--. 1 ishanu ishanu 207K Nov 16 12:31  shap2.png
# -rw-rw-r--. 1 ishanu ishanu 214K Nov 16 12:31  shap3.png
# -rw-rw-r--. 1 ishanu ishanu  410 Nov 16 12:31  tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 234K Nov 16 12:31  shapX.png
# -rw-rw-r--. 1 ishanu ishanu 1.8K Nov 16 12:31  tmptree.dot
# -rw-rw-r--. 1 ishanu ishanu  239 Nov 16 12:31  tmp.tex
# drwxrwxr-x. 3 ishanu ishanu 4.0K Nov 16 12:31  tex
# -rw-rw-r--. 1 ishanu ishanu 1.1M Nov 16 12:31  tmptree0.png
# -rw-rw-r--. 1 ishanu ishanu 1.8K Nov 16 12:31  tree.dot
# -rw-rw-r--. 1 ishanu ishanu 1.1M Nov 16 12:31  tmptree1.png
# -rw-rw-r--. 1 ishanu ishanu 1.2M Nov 16 12:31  tree0.png
# -rw-rw-r--. 1 ishanu ishanu 928K Nov 16 12:31  tree1.png
# -rw-rw-r--. 1 ishanu ishanu  14K Nov 16 12:31  updated_bsnip001_L3_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Nov 16 12:31  updated_bsnip001_L2_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Nov 16 12:31  updated_bsnip001_L1_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu 482K Nov 16 12:31  tree2.png
# -rw-rw-r--. 1 ishanu ishanu 105K Nov 16 12:31  updatedbsnip001_L3.pdf
# -rw-rw-r--. 1 ishanu ishanu 123K Nov 16 12:31  updatedbsnip001_L1.pdf
# drwxrwxr-x. 4 ishanu ishanu 4.0K Nov 16 12:33  2022summer
# -rw-rw-r--. 1 ishanu ishanu 402K Nov 16 12:37  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 206K Nov 30 09:26  ROC12vall_3vall_clinical_cognitive_eegx.png
# -rw-rw-r--. 1 ishanu ishanu 148K Nov 30 09:26  ROC2vall_3vall_clinical_cognitive_eeg.png
# -rw-rw-r--. 1 ishanu ishanu 179K Nov 30 09:26  ROC2vall_3vall_clinical_cognitive_eeg_delvar.png
# -rw-rw-r--. 1 ishanu ishanu  60K Nov 30 09:26  accvsitemnumber1eegplus.png
# -rw-rw-r--. 1 ishanu ishanu  82K Nov 30 09:26  accvsitemnumber_eegplus.png
# -rw-rw-r--. 1 ishanu ishanu  57K Nov 30 09:26  accvsitemnumber1eegplus_delvar.png
# -rw-rw-r--. 1 ishanu ishanu  81K Nov 30 09:26  accvsitemnumber_eegplus_delvar.png
# -rw-rw-r--. 1 ishanu ishanu 230K Nov 30 09:26  bsnip001-new_multi_classifier_optimization-Copy2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 386K Nov 30 09:26  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage2-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 239K Nov 30 09:26  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage2-Copy2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 182K Nov 30 09:26  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage3_shap.ipynb
# -rw-rw-r--. 1 ishanu ishanu 308K Nov 30 09:26  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage3eeg-variables_deleted.ipynb
# -rw-rw-r--. 1 ishanu ishanu 310K Nov 30 09:26  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage3eeg.ipynb
# -rw-rw-r--. 1 ishanu ishanu 5.5K Nov 30 09:26  imp_noBACSeeg.xls
# -rw-rw-r--. 1 ishanu ishanu 5.5K Nov 30 09:26  imp_noBACSeeg_delvar.xls
# -rw-rw-r--. 1 ishanu ishanu 5.5K Nov 30 09:26  imp123eegx.xls
# -rw-rw-r--. 1 ishanu ishanu 538K Nov 30 09:26  imp_small123eegx.png
# -rw-rw-r--. 1 ishanu ishanu 535K Nov 30 09:26  imp_small_eeg.png
# -rw-rw-r--. 1 ishanu ishanu 503K Nov 30 09:26  imp_small_eeg_delvar.png
# -rw-rw-r--. 1 ishanu ishanu 1.3M Nov 30 09:26  model123eegshap.mod
# -rw-rw-r--. 1 ishanu ishanu 505K Nov 30 09:26  model23eeg.mod
# -rw-rw-r--. 1 ishanu ishanu 512K Nov 30 09:26  model23eeg_delvar.mod
# drwxrwxr-x. 2 ishanu ishanu 4.0K Nov 30 09:26  phase3_results
# -rw-rw-r--. 1 ishanu ishanu 121K Nov 30 09:26  shap1eeg.png
# -rw-rw-r--. 1 ishanu ishanu 155K Nov 30 09:26  shap2eeg.png
# -rw-rw-r--. 1 ishanu ishanu 207K Nov 30 09:26  shap3eeg.png
# -rw-rw-r--. 1 ishanu ishanu 188K Nov 30 09:26  shapXeeg.png
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:30  model123eeg.mod_0
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:31  model123eeg.mod_1
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:31  model123eeg.mod_2
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:31  model123eeg.mod_3
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:32  model123eeg.mod_4
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:32  model123eeg.mod_5
# -rw-rw-r--. 1 ishanu ishanu  23K Nov 30 09:32  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage3_modelingforshap.ipynb
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:32  model123eeg.mod_6
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:33  model123eeg.mod_7
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:33  model123eeg.mod_8
# -rw-rw-r--. 1 ishanu ishanu 1.5M Nov 30 09:33  model123eeg.mod_9

# %%
# load model
import dill
with open('model123eeg.mod_0','rb') as f:
    M=dill.load(f)

# %%
def pltROC(M,VAR,ax,FS=14):
    plt.style.use('fivethirtyeight')
    ROC=M[VAR]['rocs']   
    auc=[]
    for key,crv in ROC.items():
        ax.plot(crv['fpr'],crv['tpr'],'.',ms=1,color='b')
        auc=np.append(auc,key)
    ax.set_xlabel('1-specificity',fontsize=FS)
    ax.set_ylabel('sensitivity',fontsize=FS)
    plt.setp(ax.get_xticklabels(), fontsize=FS);
    plt.setp(ax.get_yticklabels(), fontsize=FS);
    ax.set_title(str(VAR)+'-vs-all (AUC: '+ str(auc.mean())[:7]+')' );
    
#plt.style.use('seaborn-whitegrid')
fig=plt.figure(figsize=[15,5])
plt.subplot(1,3,1)
pltROC(M,1,plt.gca(),FS=16)

plt.subplot(1,3,2)
pltROC(M,2,plt.gca(),FS=16)

plt.subplot(1,3,3)
pltROC(M,3,plt.gca(),FS=16)

plt.savefig('ROC12vall_3vall_clinical_cognitive_eegx.png',dpi=400,bbox_inches='tight',transparent=True)

# %%
M.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
CF=np.zeros([3,3])
s2=Rs.s1.values[0]
s3=Rs.s2.values[0]
c2=Rs.c1.values[0]
c3=Rs.c2.values[0]
CF=[[c2*c3,1-c2,c2*(1-c3)],[(1-s2)*(1-s3),s2,(1-s2)*s3],[c2*(1-s3),1-c2,c2*s3]]

CF=pd.DataFrame(CF,columns=['B1','B2','B3'])
CF.index=CF.columns
CF
# Out:
#           B1        B2        B3
# B1  0.883600  0.060000  0.056400
# B2  0.003842  0.976401  0.019757
# B3  0.153025  0.060000  0.786975

# %%
feature_names=df.columns
feature_names=feature_names[1:]

IMP1=M[1]['estimator'].feature_importances_
IMP2=M[2]['estimator'].feature_importances_
IMP3=M[3]['estimator'].feature_importances_
plt.style.use('fivethirtyeight')
plt.style.use('ggplot')
IMPdf=pd.DataFrame({'bio3_vs_all':IMP3,'bio2_vs_all':IMP2,'bio1_vs_all':IMP1})


IMPdf.index=feature_names
plt.figure(figsize=[18,4])
ax=IMPdf[IMPdf['bio3_vs_all']>0.005].plot(kind='bar',ax=plt.gca(),width=1)
FS=12
ax.set_xlabel('feature names',fontsize=FS)
ax.set_ylabel('normalized weight',fontsize=FS)
plt.setp(ax.get_xticklabels(), fontsize=FS);
plt.setp(ax.get_yticklabels(), fontsize=FS);
#ax.set_title(str(VAR)+'-vs-all (AUC: '+ str(auc.mean())[:7]+')' );

plt.savefig('imp_small123eegx.png',dpi=400,bbox_inches='tight',transparent=True)

# %%
IMPdf.sort_values('bio3_vs_all',ascending=False)
# Out:
#                                                 bio3_vs_all  bio2_vs_all  \
# Anti_prop_error_within_Impute_Age_Sex_adjusted     0.174922     0.043082
# EEG5                                               0.053354     0.056795
# SST                                                0.040565     0.015378
# BACS                                               0.037898     0.016365
# IEA                                                0.031049     0.023132
# ...                                                     ...          ...
# panss_g16                                          0.000000     0.000000
# LATENCY                                            0.000000     0.000000
# BSNIP1vs2                                          0.000000     0.005802
# Psychosis                                          0.000000     0.000000
# madrs_3                                            0.000000     0.006173
#
#                                                 bio1_vs_all
# Anti_prop_error_within_Impute_Age_Sex_adjusted     0.002556
# EEG5                                               0.108075
# SST                                                0.000300
# BACS                                               0.003273
# IEA                                                0.085122
# ...                                                     ...
# panss_g16                                          0.001494
# LATENCY                                            0.004539
# BSNIP1vs2                                          0.002294
# Psychosis                                          0.000000
# madrs_3                                            0.000500
#
# [90 rows x 3 columns]

# %%
i1=IMPdf.sort_values('bio1_vs_all',ascending=False).head(10)
i2=IMPdf.sort_values('bio2_vs_all',ascending=False).head(10)
i3=IMPdf.sort_values('bio3_vs_all',ascending=False).head(10)
if_=pd.DataFrame({'B1_vs_all':i1.index,'B2_vs_all':i2.index,'B3_vs_all':i3.index})
if_.to_excel('imp123eegx.xls')
# Out:
# /home/ishanu/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """

# %%
RES=pd.concat([pd.concat([getRES(df0,MAX_DEPTH=m,MODELfile='tmp.mod')[0] for m in tqdm(np.arange(6,12))]) for run in tqdm(range(20))])
# Out:
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:19<01:38, 19.76s/it]
#  33%|███████████████                              | 2/6 [00:39<01:19, 19.81s/it]
#  50%|██████████████████████▌                      | 3/6 [00:59<00:59, 19.73s/it]
#  67%|██████████████████████████████               | 4/6 [01:19<00:39, 19.86s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:39<00:19, 19.95s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:00<00:00, 20.02s/it]
#   5%|██▏                                        | 1/20 [02:00<38:02, 120.13s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:19<01:38, 19.68s/it]
#  33%|███████████████                              | 2/6 [00:39<01:19, 19.78s/it]
#  50%|██████████████████████▌                      | 3/6 [00:59<00:59, 19.90s/it]
#  67%|██████████████████████████████               | 4/6 [01:20<00:40, 20.05s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:40<00:20, 20.21s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:01<00:00, 20.30s/it]
#  10%|████▎                                      | 2/20 [04:01<36:11, 120.64s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:40, 20.00s/it]
#  33%|███████████████                              | 2/6 [00:39<01:19, 19.96s/it]
#  50%|██████████████████████▌                      | 3/6 [00:59<00:59, 19.94s/it]
#  67%|██████████████████████████████               | 4/6 [01:19<00:39, 19.96s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:40<00:20, 20.05s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:00<00:00, 20.05s/it]
#  15%|██████▍                                    | 3/20 [06:02<34:09, 120.55s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:19<01:36, 19.24s/it]
#  33%|███████████████                              | 2/6 [00:38<01:17, 19.27s/it]
#  50%|██████████████████████▌                      | 3/6 [00:58<00:58, 19.42s/it]
#  67%|██████████████████████████████               | 4/6 [01:18<00:39, 19.66s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:38<00:19, 19.79s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:59<00:00, 19.84s/it]
#  20%|████████▌                                  | 4/20 [08:01<32:01, 120.09s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:19<01:36, 19.21s/it]
#  33%|███████████████                              | 2/6 [00:38<01:17, 19.33s/it]
#  50%|██████████████████████▌                      | 3/6 [00:58<00:58, 19.45s/it]
#  67%|██████████████████████████████               | 4/6 [01:18<00:39, 19.58s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:38<00:19, 19.70s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:58<00:00, 19.77s/it]
#  25%|██████████▊                                | 5/20 [09:59<29:54, 119.66s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:18<01:31, 18.36s/it]
#  33%|███████████████                              | 2/6 [00:37<01:13, 18.46s/it]
#  50%|██████████████████████▌                      | 3/6 [00:56<00:55, 18.62s/it]
#  67%|██████████████████████████████               | 4/6 [01:15<00:37, 18.80s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:34<00:18, 18.96s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:54<00:00, 19.03s/it]
#  30%|████████████▉                              | 6/20 [11:54<27:32, 118.02s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:18<01:32, 18.47s/it]
#  33%|███████████████                              | 2/6 [00:37<01:14, 18.57s/it]
#  50%|██████████████████████▌                      | 3/6 [00:56<00:56, 18.72s/it]
#  67%|██████████████████████████████               | 4/6 [01:15<00:37, 18.83s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:34<00:19, 19.00s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:54<00:00, 19.02s/it]
#  35%|███████████████                            | 7/20 [13:48<25:19, 116.85s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:18<01:31, 18.36s/it]
#  33%|███████████████                              | 2/6 [00:36<01:13, 18.42s/it]
#  50%|██████████████████████▌                      | 3/6 [00:55<00:55, 18.56s/it]
#  67%|██████████████████████████████               | 4/6 [01:14<00:37, 18.75s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:34<00:18, 18.87s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:53<00:00, 18.95s/it]
#  40%|█████████████████▏                         | 8/20 [15:41<23:10, 115.91s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:18<01:33, 18.65s/it]
#  33%|███████████████                              | 2/6 [00:38<01:15, 18.93s/it]
#  50%|██████████████████████▌                      | 3/6 [00:58<00:58, 19.39s/it]
#  67%|██████████████████████████████               | 4/6 [01:19<00:39, 19.68s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:39<00:19, 19.86s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:59<00:00, 19.95s/it]
#  45%|███████████████████▎                       | 9/20 [17:41<21:27, 117.04s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:40, 20.16s/it]
#  33%|███████████████                              | 2/6 [00:40<01:20, 20.09s/it]
#  50%|██████████████████████▌                      | 3/6 [01:00<01:00, 20.06s/it]
#  67%|██████████████████████████████               | 4/6 [01:20<00:40, 20.27s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:41<00:20, 20.48s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:03<00:00, 20.50s/it]
#  50%|█████████████████████                     | 10/20 [19:44<19:48, 118.84s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:42, 20.44s/it]
#  33%|███████████████                              | 2/6 [00:41<01:21, 20.49s/it]
#  50%|██████████████████████▌                      | 3/6 [01:01<01:01, 20.63s/it]
#  67%|██████████████████████████████               | 4/6 [01:23<00:41, 20.92s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:45<00:21, 21.07s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:06<00:00, 21.12s/it]
#  55%|███████████████████████                   | 11/20 [21:51<18:10, 121.20s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:41, 20.27s/it]
#  33%|███████████████                              | 2/6 [00:41<01:21, 20.43s/it]
#  50%|██████████████████████▌                      | 3/6 [01:02<01:02, 20.67s/it]
#  67%|██████████████████████████████               | 4/6 [01:23<00:41, 20.88s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:45<00:21, 21.10s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:07<00:00, 21.21s/it]
#  60%|█████████████████████████▏                | 12/20 [23:58<16:24, 123.03s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:41, 20.31s/it]
#  33%|███████████████                              | 2/6 [00:40<01:21, 20.29s/it]
#  50%|██████████████████████▌                      | 3/6 [01:01<01:01, 20.37s/it]
#  67%|██████████████████████████████               | 4/6 [01:22<00:41, 20.54s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:42<00:20, 20.46s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:03<00:00, 20.56s/it]
#  65%|███████████████████████████▎              | 13/20 [26:02<14:21, 123.14s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:19<01:36, 19.39s/it]
#  33%|███████████████                              | 2/6 [00:40<01:19, 19.77s/it]
#  50%|██████████████████████▌                      | 3/6 [01:00<00:59, 19.95s/it]
#  67%|██████████████████████████████               | 4/6 [01:21<00:40, 20.17s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:41<00:20, 20.32s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:03<00:00, 20.51s/it]
#  70%|█████████████████████████████▍            | 14/20 [28:05<12:18, 123.11s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:42, 20.58s/it]
#  33%|███████████████                              | 2/6 [00:42<01:24, 21.04s/it]
#  50%|██████████████████████▌                      | 3/6 [01:05<01:04, 21.61s/it]
#  67%|██████████████████████████████               | 4/6 [01:29<00:44, 22.34s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:53<00:22, 22.72s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:17<00:00, 22.95s/it]
#  75%|███████████████████████████████▌          | 15/20 [30:22<10:37, 127.50s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:23<01:55, 23.13s/it]
#  33%|███████████████                              | 2/6 [00:47<01:33, 23.41s/it]
#  50%|██████████████████████▌                      | 3/6 [01:12<01:11, 23.95s/it]
#  67%|██████████████████████████████               | 4/6 [01:37<00:48, 24.15s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:58<00:23, 23.27s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:19<00:00, 23.32s/it]
#  80%|█████████████████████████████████▌        | 16/20 [32:42<08:44, 131.22s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:43, 20.68s/it]
#  33%|███████████████                              | 2/6 [00:41<01:22, 20.63s/it]
#  50%|██████████████████████▌                      | 3/6 [01:01<01:01, 20.65s/it]
#  67%|██████████████████████████████               | 4/6 [01:22<00:41, 20.78s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:43<00:20, 20.83s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:05<00:00, 20.87s/it]
#  85%|███████████████████████████████████▋      | 17/20 [34:48<06:28, 129.43s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:40, 20.07s/it]
#  33%|███████████████                              | 2/6 [00:40<01:20, 20.19s/it]
#  50%|██████████████████████▌                      | 3/6 [01:01<01:01, 20.37s/it]
#  67%|██████████████████████████████               | 4/6 [01:22<00:41, 20.59s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:43<00:20, 20.85s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:05<00:00, 20.88s/it]
#  90%|█████████████████████████████████████▊    | 18/20 [36:53<04:16, 128.18s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:41, 20.32s/it]
#  33%|███████████████                              | 2/6 [00:41<01:21, 20.44s/it]
#  50%|██████████████████████▌                      | 3/6 [01:01<01:01, 20.57s/it]
#  67%|██████████████████████████████               | 4/6 [01:23<00:41, 20.80s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:45<00:21, 21.15s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:06<00:00, 21.12s/it]
#  95%|███████████████████████████████████████▉  | 19/20 [39:00<02:07, 127.74s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:20<01:43, 20.69s/it]
#  33%|███████████████                              | 2/6 [00:41<01:23, 20.77s/it]
#  50%|██████████████████████▌                      | 3/6 [01:03<01:03, 21.00s/it]
#  67%|██████████████████████████████               | 4/6 [01:24<00:42, 21.17s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [01:46<00:21, 21.46s/it]
# 100%|█████████████████████████████████████████████| 6/6 [02:09<00:00, 21.50s/it]
# 100%|██████████████████████████████████████████| 20/20 [41:09<00:00, 123.45s/it]

# %%
RES
# Out:
#        c1    c2       acc        s1        s2    nq_mean  nq_median
# 590  0.89  0.90  0.808646  0.841733  0.778865  19.249716       19.0
# 594  0.89  0.94  0.811135  0.889064  0.611797  21.619750       22.0
# 740  0.94  0.90  0.850667  0.858300  0.845164  25.448354       26.0
# 744  0.94  0.94  0.864503  0.850093  0.803558  27.019296       27.0
# 744  0.94  0.94  0.879436  0.895214  0.830567  27.774120       28.0
# ..    ...   ...       ...       ...       ...        ...        ...
# 594  0.89  0.94  0.821690  0.880330  0.678248  22.170261       22.0
# 740  0.94  0.90  0.843416  0.836713  0.829958  23.780931       24.0
# 744  0.94  0.94  0.873089  0.874806  0.819849  26.429058       27.0
# 744  0.94  0.94  0.887611  0.902855  0.869036  29.940976       31.0
# 774  0.95  0.94  0.898051  0.905872  0.894214  29.283768       29.0
#
# [120 rows x 7 columns]

# %%
RES.set_index('nq_median').acc.plot(style='ko')

# %%
ax=sns.regplot(x=RES.nq_mean,y=RES.acc,ci=99.999,lowess=True)
ax.set_xlabel('mean number of items')
ax.set_ylabel('mean accuracy')
#plt.savefig('accvsitemnumber.png',dpi=200,bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'mean accuracy')

# %%
plt.style.use('fivethirtyeight')
df=pd.DataFrame(RES.set_index('nq_mean').acc)
import scipy.stats as stats
import statsmodels.api as sm
from scipy import interpolate
from scipy.interpolate import interp1d

lowess = sm.nonparametric.lowess
df.index=df.index.astype(float)
df=df.sort_index()
S=.2
RUNS=50
DF=df
   
for i in range(RUNS):
    X=df.sample(int(np.round(S*df.index.size))).sort_index().reset_index().values

    z = lowess(X[:,1], X[:,0], frac= .25)
    f = interp1d(z[:,0], z[:,1])
    Y=f(X[:,0])
    DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
DF=DF.interpolate(method='index',order=3,limit_direction='both')
STD=pd.DataFrame(2.62*(DF.std(axis=1)/np.sqrt(RUNS)))
Mf=pd.DataFrame(DF.mean(axis=1)).assign(sm=STD)
Mf.columns=['mn','sm']
ax=Mf.mn.plot()
plt.fill_between(Mf.index,Mf.mn-Mf.sm,Mf.mn+Mf.sm,alpha=.35)
ax.set_xlabel('mean number of items')
ax.set_ylabel('mean accuracy')
plt.savefig('accvsitemnumbereegx.png',dpi=200,bbox_inches='tight',transparent=True)
# Out:
# /home/ishanu/.local/lib/python3.7/site-packages/pandas/core/frame.py:9138: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   sort=sort,
