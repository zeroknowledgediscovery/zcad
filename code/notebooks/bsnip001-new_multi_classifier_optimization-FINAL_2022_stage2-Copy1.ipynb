# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from scipy.spatial import ConvexHull
from tqdm import tqdm
import random
plt.style.use('ggplot')
import pickle
from sklearn import tree
from sklearn.tree import export_graphviz
from joblib import dump, load
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
# %matplotlib inline
from sklearn.impute import SimpleImputer
from scipy import interpolate
from scipy.interpolate import interp1d

# %%
MAX_DEPTH=6
NUMESTIMATORS=2

# %%
def getAuc(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,FPR=[],TPR=[],VERBOSE=False, USE_ONLY=None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit,class_weight='balanced'),
                RandomForestClassifier(n_estimators=n_estimators,
                                       max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                ExtraTreesClassifier(n_estimators=n_estimators,
                                     max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict_proba(X_test)
        #print(X_test,y_pred)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        auc=metrics.auc(fpr, tpr)
        if VERBOSE:
            print(auc)

        FPR=np.append(FPR,fpr)
        TPR=np.append(TPR,tpr)
    points=np.array([[a[0],a[1]] for a in zip(FPR,TPR)])
    hull = ConvexHull(points)
    x=np.argsort(points[hull.vertices,:][:,0])
    auc=metrics.auc(points[hull.vertices,:][x,0],points[hull.vertices,:][x,1])
    return auc,CLASSIFIERS


def saveFIG(filename='tmp.pdf',AXIS=False):
    '''
        save fig for publication
    '''
    import pylab as plt
    plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
    plt.margins(0,0)
    if not AXIS:
        plt.gca().xaxis.set_major_locator(plt.NullLocator())
        plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig(filename,dpi=300, bbox_inches = 'tight',
                pad_inches = 0,transparent=False) 
    return

# %%
def getacc(c1,c2,p1,p2,p3,f1,f2):
    s1=f1(1-c1)
    s2=f2(1-c2)
    A=(c1*c2*(1-p1)*(1-p2))/((c1*(1-p1)+(1-s1)*p1)*(c2*(1-p2)+(1-s2)*p2))
    B=(1-s1)*p1 - (1-c1)*(1-p1) + (1-s2)*p2 - (1-c2)*(1-p2) + p3
    return s1*p1+s2*p2+ A*B

# %%
def getCoverage(model,verbose=True):
    '''
        return how many distinct items (questions)
        are used in the model set.
        This includes the set of questions being
        covered by all forms that may be 
        generated by the model set
    '''
    FS=[]
    for m in model:
        for count in range(len(m.estimators_)):
            clf=m.estimators_[count]
            fs=clf.tree_.feature[clf.tree_.feature>0]
            FS=np.array(list(set(np.append(FS,fs))))
    if verbose:
        print("Number of items used: ", FS.size)
    return FS

def getConfusion(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,CONFUSION={},VERBOSE=False, USE_ONLY=None,target_names = None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit),
                RandomForestClassifier(n_estimators=n_estimators,class_weight='balanced',
                                       max_depth=max_depth,min_samples_split=minsplit),
                ExtraTreesClassifier(n_estimators=n_estimators,class_weight='balanced',
                                     max_depth=max_depth,min_samples_split=minsplit),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict(X_test)
        print(y_test,y_pred)
        cmat=confusion_matrix(y_test, y_pred)
        acc=accuracy_score(y_test, y_pred)
        
        CONFUSION[clf]=cmat
        
        if VERBOSE:
            print(classification_report(y_test, y_pred, target_names=target_names))
            print('Confusion MAtrix:\n', cmat)
            print(' ')
            print('Accuracy:', acc)

        
    return CONFUSION,acc,y_test,y_pred

# %%
def getFmap(CLFstar,X,y):
    auc_=[]
    ROC={}
    fpr_ = np.linspace(0, 1, num=20, endpoint=True)
    for run in np.arange(1000):
        clf=CLFstar
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
        y_pred=clf.predict_proba(X_test)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        f = interp1d(fpr, tpr)
        th = interp1d(fpr, thresholds)
        auc_=np.append(auc_,metrics.auc(fpr_, f(fpr_)))
        ROC[metrics.auc(fpr, tpr)]={'fpr':fpr_,'tpr':f(fpr_),'thresholds':th(fpr_)}

    TPR=[]
    for a in ROC.keys():
        TPR=np.append(TPR,ROC[a]['tpr'])
    TPR=TPR.reshape(int(len(TPR)/len(fpr_)),len(fpr_))
    medTPR=np.median(TPR,axis=0)
    return interpolate.interp1d(fpr_,np.median(TPR,axis=0) ), ROC

# %%
xf=pd.read_csv('./2022summer/adeptphase2/Cognition.csv',index_col=0)
xf.index.name='subject_id'
xf=xf.drop('DX',axis=1)
xf.head()
# Out:
#              Age  Sex  BSNIP1vs2  Psychosis  BACS_COMP_Z_within  \
# subject_id
# 1           21.0  1.0          1          1           -1.966352
# 4           19.0  1.0          1          1            0.387837
# 17          27.0  2.0          1          1           -1.116494
# 40          60.0  1.0          1          0            1.730613
# 50          48.0  1.0          1          0           -0.177776
#
#             BACS_Verb_Mem_within_imputed  BACS_Dig_Seq_z_within_imputed  \
# subject_id
# 1                              -1.239086                      -1.894718
# 4                               1.314364                       1.215812
# 17                             -0.934523                      -1.033015
# 40                              1.099544                       0.861462
# 50                             -1.113056                      -0.643202
#
#             BACS_Tok_Mot_z_within_imputed  BACS_Verb_Flu_z_within_imputed  \
# subject_id
# 1                               -1.975991                       -2.157289
# 4                                0.743739                       -1.473370
# 17                              -0.698348                       -0.990980
# 40                               2.236269                        0.325097
# 50                              -0.058674                        0.809957
#
#             BACS_Sym_Cod_z_within_imputed  BACS_Tower_z_within_imputed  \
# subject_id
# 1                               -1.777237                    -2.668861
# 4                                0.030376                    -0.117295
# 17                              -1.574574                     0.132828
# 40                               2.180177                     0.990692
# 50                              -0.374233                     0.313604
#
#             ConsensusWRAT  Pro_NoGap_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                   103.0                                   1.29400
# 4                   125.0                                  -0.81433
# 17                  105.0                                  -0.79924
# 40                  126.0                                  -0.22708
# 50                   80.0                                  -0.39351
#
#             Pro_Gap_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                         1.250300
# 4                                        -0.067136
# 17                                       -1.156300
# 40                                        0.110990
# 50                                       -0.492320
#
#             Pro_Overlap_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                             1.365000
# 4                                            -0.717420
# 17                                           -0.846560
# 40                                            0.099724
# 50                                           -1.364300
#
#             Anti_Corr_Lat_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                                1.49310
# 4                                               -0.16308
# 17                                              -1.18750
# 40                                              -1.02700
# 50                                                   NaN
#
#             Anti_Error_Lat_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                                 1.84340
# 4                                                -0.45067
# 17                                               -0.90979
# 40                                               -0.69790
# 50                                                    NaN
#
#             Anti_prop_error_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                                  0.17735
# 4                                                  0.75196
# 17                                                 2.08830
# 40                                                -1.07770
# 50                                                     NaN
#
#             SSGoDiff_standwithin  SSTProportionError_standwithin
# subject_id
# 1                      -0.086522                       -0.908397
# 4                       0.406882                       -0.055350
# 17                     -1.289105                        1.082046
# 40                           NaN                             NaN
# 50                     -0.654831                       -0.410787

# %%
df=pd.read_csv('combined_bsnip.csv',index_col=0).drop('DSM',axis=1)
df=df.join(xf)#.head()

# %%
#df=pd.read_csv('combined_bsnip.csv',index_col=0).drop('DSM',axis=1)
df=df.drop('project',axis=1)
df=df.drop('BACS_COMP_Z_within',axis=1)
df.head()
# Out:
#             Biotype  panss_p1  panss_p2  panss_p3  panss_p4  panss_p5  \
# subject_id
# 1                 2       4.0       3.0       4.0       1.0       3.0
# 4                 3       3.0       1.0       3.0       1.0       2.0
# 17                2       2.0       2.0       2.0       1.0       1.0
# 53                2       4.0       3.0       5.0       2.0       1.0
# 73                2       6.0       5.0       6.0       4.0       5.0
#
#             panss_p6  panss_p7  panss_n1  panss_n2  ...  \
# subject_id                                          ...
# 1                2.0       1.0       4.0       3.0  ...
# 4                2.0       1.0       3.0       4.0  ...
# 17               2.0       1.0       3.0       3.0  ...
# 53               3.0       1.0       5.0       1.0  ...
# 73               6.0       6.0       1.0       4.0  ...
#
#             BACS_Tower_z_within_imputed  ConsensusWRAT  \
# subject_id
# 1                             -2.668861          103.0
# 4                             -0.117295          125.0
# 17                             0.132828          105.0
# 53                            -1.243126           84.0
# 73                            -0.077277           93.0
#
#             Pro_NoGap_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                            1.29400
# 4                                           -0.81433
# 17                                          -0.79924
# 53                                           0.71209
# 73                                          -1.70400
#
#             Pro_Gap_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                         1.250300
# 4                                        -0.067136
# 17                                       -1.156300
# 53                                        1.625000
# 73                                       -1.294200
#
#             Pro_Overlap_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                             1.365000
# 4                                            -0.717420
# 17                                           -0.846560
# 53                                            1.195700
# 73                                           -0.096217
#
#             Anti_Corr_Lat_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                                1.49310
# 4                                               -0.16308
# 17                                              -1.18750
# 53                                               3.12500
# 73                                               0.25845
#
#             Anti_Error_Lat_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                                 1.84340
# 4                                                -0.45067
# 17                                               -0.90979
# 53                                                0.18100
# 73                                               -1.65310
#
#             Anti_prop_error_within_Impute_Age_Sex_adjusted  \
# subject_id
# 1                                                 0.177350
# 4                                                 0.751960
# 17                                                2.088300
# 53                                                0.029824
# 73                                                0.617100
#
#             SSGoDiff_standwithin  SSTProportionError_standwithin
# subject_id
# 1                      -0.086522                       -0.908397
# 4                       0.406882                       -0.055350
# 17                     -1.289105                        1.082046
# 53                     -1.082237                        1.224220
# 73                     -2.243046                        2.645965
#
# [5 rows x 78 columns]

# %%
feature_names=df.columns
feature_names=feature_names[1:]
feature_names
# Out:
# Index(['panss_p1', 'panss_p2', 'panss_p3', 'panss_p4', 'panss_p5', 'panss_p6',
#        'panss_p7', 'panss_n1', 'panss_n2', 'panss_n3', 'panss_n4', 'panss_n5',
#        'panss_n6', 'panss_n7', 'panss_g1', 'panss_g2', 'panss_g3', 'panss_g4',
#        'panss_g5', 'panss_g6', 'panss_g7', 'panss_g8', 'panss_g9', 'panss_g10',
#        'panss_g11', 'panss_g12', 'panss_g13', 'panss_g14', 'panss_g15',
#        'panss_g16', 'madrs_1', 'madrs_2', 'madrs_3', 'madrs_4', 'madrs_5',
#        'madrs_6', 'madrs_7', 'madrs_8', 'madrs_9', 'madrs_10', 'young_1',
#        'young_2', 'young_3', 'young_4', 'young_5', 'young_6', 'young_7',
#        'young_8', 'young_9', 'young_10', 'young_11', 'sfs_setotal',
#        'sfs_ictotal', 'sfs_ipcptotal', 'sfs_ipcctotal', 'sfs_retotal',
#        'sfs_prototal', 'sfs_oetotal', 'Age', 'Sex', 'BSNIP1vs2', 'Psychosis',
#        'BACS_Verb_Mem_within_imputed', 'BACS_Dig_Seq_z_within_imputed',
#        'BACS_Tok_Mot_z_within_imputed', 'BACS_Verb_Flu_z_within_imputed',
#        'BACS_Sym_Cod_z_within_imputed', 'BACS_Tower_z_within_imputed',
#        'ConsensusWRAT', 'Pro_NoGap_within_Impute_Age_Sex_adjusted',
#        'Pro_Gap_within_Impute_Age_Sex_adjusted',
#        'Pro_Overlap_within_Impute_Age_Sex_adjusted',
#        'Anti_Corr_Lat_within_Impute_Age_Sex_adjusted',
#        'Anti_Error_Lat_within_Impute_Age_Sex_adjusted',
#        'Anti_prop_error_within_Impute_Age_Sex_adjusted',
#        'SSGoDiff_standwithin', 'SSTProportionError_standwithin'],
#       dtype='object')

# %%
#df=df[df['Biotype']==3]
df=df.dropna()
df0=df
[p1,p2,p3]=(df0.Biotype.value_counts()/df0.Biotype.value_counts().sum()).values

# %%
df.Biotype.value_counts()
# 3 is HC
# Out:
# 3    397
# 1    348
# 2    307
# Name: Biotype, dtype: int64

# %%
def getRES(df0,MAX_DEPTH=6,NUMESTIMATORS=2,MODELfile='model123.mod'):
    df=df0
    X=df.iloc[:,1:].values
    y=df.Biotype.values#.astype(str)
    y=[(int(x)==1)+0 for x in y ]

    MODEL={}
    
    ACC=[]
    CLFh={}
    for run in np.arange(500):
        auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
                   minsplit=2,VERBOSE=False, USE_ONLY=[2])
        ACC=np.append(ACC,auc)
        if auc > 0.5:
            CLFh[auc]=CLFS
    CLFstar1=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
    f0,ROC0=getFmap(CLFstar1,X,y)
    
    MODEL[1]={'estimator':CLFstar1,'fmap':f0,'rocs':ROC0}
    
    df=df0
    X=df.iloc[:,1:].values
    y=df.Biotype.values#.astype(str)
    y=[(int(x)==2)+0 for x in y ]

    
    ACC=[]
    CLFh={}
    for run in np.arange(500):
        auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
                   minsplit=2,VERBOSE=False, USE_ONLY=[2])
        ACC=np.append(ACC,auc)
        if auc > 0.5:
            CLFh[auc]=CLFS
    CLFstarA=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
    f1,ROCA=getFmap(CLFstarA,X,y)
    
    MODEL[2]={'estimator':CLFstarA,'fmap':f1,'rocs':ROCA}

    #df=df0[df0.Biotype.isin([1,5])]
    df=df0
    X=df.iloc[:,1:].values
    y=df.Biotype.values#.astype(str)
    y=[(int(x)==3)+0 for x in y ]

    ACC=[]
    CLFh={}
    for run in np.arange(500):
        auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
                   minsplit=2,VERBOSE=False, USE_ONLY=[2])
        ACC=np.append(ACC,auc)
        if auc > 0.5:
            CLFh[auc]=CLFS
    CLFstarB=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
    f2,ROCB=getFmap(CLFstarB,X,y)
    MODEL[3]={'estimator':CLFstarB,'fmap':f2,'rocs':ROCB}

    R=[]
    for i in np.arange(.7,.99,.01):
        for j in np.arange(.7,.99,.01):
            R=np.append(R,[i,j,getacc(i,j,p1,p2,p3,f1,f2)])
    R=pd.DataFrame(R.reshape(len(R)//3,3))
    R.columns=['c1','c2','acc']
    R['s1']=f1(1-R.c1)
    R['s2']=f2(1-R.c2)


    X_test=df.values.astype(np.float32)
    L=[]

    for sample_id in np.arange(len(X_test)):
        Node_index=[]
        for i in CLFstarA.estimators_:
            threshold= i.tree_.threshold
            feature= i.tree_.feature
            node_indicator = i.tree_.decision_path(X_test)
            leaf_id = i.tree_.apply(X_test)

            node_index = node_indicator.indices[
            node_indicator.indptr[sample_id] : node_indicator.indptr[sample_id + 1]]
            Node_index=np.append(Node_index,node_index)

        for i in CLFstarB.estimators_:
            threshold= i.tree_.threshold
            feature= i.tree_.feature
            node_indicator = i.tree_.decision_path(X_test)
            leaf_id = i.tree_.apply(X_test)

            node_index = node_indicator.indices[
            node_indicator.indptr[sample_id] : node_indicator.indptr[sample_id + 1]]
            Node_index=np.append(Node_index,node_index)
        L=np.append(L,len(set(Node_index))-2)
    L=np.array(L)
    #print(np.mean(L),np.median(L))
    #sns.displot(L);


    RES=R.sort_values('acc',ascending=False).head(1)
    RES['nq_mean']=np.mean(L)
    RES['nq_median']=np.median(L)
    
    import dill
    with open(MODELfile, "wb") as dill_file:
        dill.dump(MODEL, dill_file)
    #dill_file.close()
    
    return RES, ROCA, ROCB, CLFstarA, CLFstarB

# %%
for i in tqdm(np.arange(10)):
    Rs,ROCa,ROCb,CLFstarA,CLFstarB=getRES(df0,MAX_DEPTH=10,MODELfile='model123.mod_'+str(i))
    #Rs
# Out:
# 100%|███████████████████████████████████████████| 10/10 [02:38<00:00, 15.81s/it]

# %%
! ls -lhtr
# Out:
# total 87M
# -rw-rw-r--. 1 ishanu ishanu  15K Jul 13  2021  3IMPFRACsczVscaff_2_.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.3K Jul 13  2021  3_X2X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  15K Jul 13  2021  3IMPFRACsczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu  408 Jul 13  2021  3_4_tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 1.6K Jul 13  2021  3_4_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu  384 Jul 13  2021  3_2__tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 956K Jul 13  2021  3_X2X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 1.5K Jul 13  2021  3_X4X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu 795K Jul 13  2021  3_X2X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 962K Jul 13  2021  3_X4X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 851K Jul 13  2021  3_X4X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 4.8M Jul 13  2021  3_XX2XX_PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 122K Jul 13  2021  3sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.6K Jul 13  2021  3_sczVscaff_2_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu 124K Jul 13  2021  3sczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu 896K Jul 13  2021  4PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 892K Jul 13  2021  4PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 4.1K Jul 13  2021  6_X2X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  15K Jul 13  2021  6IMPFRACsczVscaff_2_.pdf
# -rw-rw-r--. 1 ishanu ishanu  15K Jul 13  2021  6IMPFRACsczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu  410 Jul 13  2021  6_4_tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 1.6K Jul 13  2021  6_4_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu  384 Jul 13  2021  6_2__tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 2.9M Jul 13  2021  6_X2X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 3.7K Jul 13  2021  6_X4X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu 2.7M Jul 13  2021  6_X2X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 2.8M Jul 13  2021  6_X4X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 2.4M Jul 13  2021  6_X4X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu  12M Jul 13  2021  6_XX2XX_PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu  15K Jul 13  2021  9IMPFRACsczVscaff_2_.pdf
# -rw-rw-r--. 1 ishanu ishanu  15K Jul 13  2021  9IMPFRACsczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu 103K Jul 13  2021  6sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.6K Jul 13  2021  6_sczVscaff_2_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu 123K Jul 13  2021  6sczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu 8.0K Jul 13  2021  9_X2X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  408 Jul 13  2021  9_4_tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 1.6K Jul 13  2021  9_4_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu  248 Jul 13  2021  9_2__tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 4.8M Jul 13  2021  9_X2X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 7.4K Jul 13  2021  9_X4X_PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu 5.4M Jul 13  2021  9_X2X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu 4.7M Jul 13  2021  9_X4X_PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu 4.8M Jul 13  2021  9_X4X_PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu  97K Jul 13  2021  9sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.6K Jul 13  2021  9_sczVscaff_2_Item_Importance_Usage.tex
# -rw-rw-r--. 1 ishanu ishanu 109K Jul 13  2021  9sczsceff.pdf
# drwxrwxr-x. 1 ishanu ishanu  316 Jul 13  2021  CAD-psych-paper
# -rw-rw-r--. 1 ishanu ishanu 2.9K Jul 13  2021  PSYtree.dot
# -rw-rw-r--. 1 ishanu ishanu  28K Jul 13  2021  PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 6.5K Jul 13  2021  PSYmodel_2_3.pkl
# -rw-rw-r--. 1 ishanu ishanu 101K Jul 13  2021  PSYCHO.DAT
# -rw-rw-r--. 1 ishanu ishanu 2.3M Jul 13  2021  PSYtree0.png
# -rw-rw-r--. 1 ishanu ishanu  25K Jul 13  2021  ResultPSY32.pdf
# -rw-rw-r--. 1 ishanu ishanu  26K Jul 13  2021  ResultPSY23.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.8M Jul 13  2021  PSYtree1.png
# -rw-rw-r--. 1 ishanu ishanu  34K Jul 13  2021  Y.csv
# -rw-rw-r--. 1 ishanu ishanu 5.0K Jul 13  2021  Untitled.ipynb
# -rw-rw-r--. 1 ishanu ishanu 4.9M Jul 13  2021  SCH+scffvxmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 2.6K Jul 13  2021  Y.dat
# drwxrwxr-x. 1 ishanu ishanu   36 Jul 13  2021  __pycache__
# -rw-rw-r--. 1 ishanu ishanu 6.2K Jul 13  2021  bck_1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 235K Jul 13  2021  bsnip.csv
# -rw-rw-r--. 1 ishanu ishanu  64K Jul 13  2021  bsnip001-Copy3.ipynb
# -rw-rw-r--. 1 ishanu ishanu  79K Jul 13  2021  bsnip001-Copy2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 142K Jul 13  2021  bsnip001-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu  47K Jul 13  2021  bsnip001-impcalculation.ipynb
# -rw-rw-r--. 1 ishanu ishanu 103K Jul 13  2021  bsnip001_L2.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Jul 13  2021  bsnip001_L2_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu 106K Jul 13  2021  bsnip001_L1.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Jul 13  2021  bsnip001_L1_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu  99K Jul 13  2021  bsnip001_L15.pdf
# -rw-rw-r--. 1 ishanu ishanu  79K Jul 13  2021  bsnip001.ipynb
# -rw-rw-r--. 1 ishanu ishanu 102K Jul 13  2021  bsnip001_L5.pdf
# -rw-rw-r--. 1 ishanu ishanu 101K Jul 13  2021  bsnip001_L3.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Jul 13  2021  bsnip001_L3_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Jul 13  2021  bsnip001_L2_importances_.pdf
# drwxrwxr-x. 1 ishanu ishanu  134 Jul 13  2021  bsnipFIG
# -rw-rw-r--. 1 ishanu ishanu 9.1K Jul 13  2021  ccx.py
# -rw-rw-r--. 1 ishanu ishanu  927 Jul 13  2021  dummy23tree.dot
# -rw-rw-r--. 1 ishanu ishanu 397K Jul 13  2021  combinedBSNIP1_BSNIP2_PARDIP_clinical_011921.xlsx
# -rw-rw-r--. 1 ishanu ishanu 522K Jul 13  2021  dummy23tree0.png
# -rw-rw-r--. 1 ishanu ishanu 529K Jul 13  2021  dummy23tree1.png
# -rw-rw-r--. 1 ishanu ishanu 1.7K Jul 13  2021  dummy32tree.dot
# -rw-rw-r--. 1 ishanu ishanu 524K Jul 13  2021  dummy23tree2.png
# -rw-rw-r--. 1 ishanu ishanu 998K Jul 13  2021  dummy32tree0.png
# -rw-rw-r--. 1 ishanu ishanu 1.7K Jul 13  2021  dummytree.dot
# -rw-rw-r--. 1 ishanu ishanu 982K Jul 13  2021  dummy32tree1.png
# -rw-rw-r--. 1 ishanu ishanu 982K Jul 13  2021  dummytree0.png
# -rw-rw-r--. 1 ishanu ishanu 127K Jul 13  2021  inferModel_.ipynb
# -rw-rw-r--. 1 ishanu ishanu 103K Jul 13  2021  inferModel_-grantdummy.ipynb
# -rw-rw-r--. 1 ishanu ishanu 955K Jul 13  2021  dummytree1.png
# -rw-rw-r--. 1 ishanu ishanu  53K Jul 13  2021  model_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 9.3K Jul 13  2021  model_2_3.pkl
# -rw-rw-r--. 1 ishanu ishanu 3.1M Jul 13  2021  movie_nncomput_combined.ipynb
# drwxrwxr-x. 1 ishanu ishanu  538 Jul 13  2021  newcodes
# -rw-rw-r--. 1 ishanu ishanu  25K Jul 13  2021  psychoByDiag.csv
# -rw-rw-r--. 1 ishanu ishanu  22K Jul 13  2021  nitems_SSvO.csv
# -rw-rw-r--. 1 ishanu ishanu 1.4M Jul 13  2021  psychosis-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 221K Jul 13  2021  psychosis-Copy2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 231K Jul 13  2021  psychosis-Copy2a.ipynb
# -rw-rw-r--. 1 ishanu ishanu 122K Jul 13  2021  psychosis-Copy3.ipynb
# -rw-rw-r--. 1 ishanu ishanu  460 Jul 13  2021  rescbd.csv
# -rw-rw-r--. 1 ishanu ishanu 698K Jul 13  2021  psychosis.ipynb
# -rw-rw-r--. 1 ishanu ishanu 295K Jul 13  2021  psychosis-Copy4.ipynb
# -rw-rw-r--. 1 ishanu ishanu 120K Jul 13  2021  sczVscaff_XX_PSYmodel_3_2.pkl
# -rw-rw-r--. 1 ishanu ishanu 102K Jul 13  2021  sczVscaff.pdf
# -rw-rw-r--. 1 ishanu ishanu  93K Jul 13  2021  sczVSall.pdf
# -rw-rw-r--. 1 ishanu ishanu  291 Jul 13  2021  roc_.csv
# -rw-rw-r--. 1 ishanu ishanu  410 Jul 13  2021  tab1.tex
# -rw-rw-r--. 1 ishanu ishanu 117K Jul 13  2021  sczsceffVS34_RAW.pdf
# -rw-rw-r--. 1 ishanu ishanu 117K Jul 13  2021  sczsceffVS34_Q+RAW.pdf
# -rw-rw-r--. 1 ishanu ishanu 117K Jul 13  2021  sczsceffVS34.pdf
# -rw-rw-r--. 1 ishanu ishanu 119K Jul 13  2021  sczsceff.pdf
# -rw-rw-r--. 1 ishanu ishanu 1.8K Jul 13  2021  tmptree.dot
# -rw-rw-r--. 1 ishanu ishanu  239 Jul 13  2021  tmp.tex
# drwxrwxr-x. 1 ishanu ishanu  274 Jul 13  2021  tex
# -rw-rw-r--. 1 ishanu ishanu 1.1M Jul 13  2021  tmptree0.png
# -rw-rw-r--. 1 ishanu ishanu 1.8K Jul 13  2021  tree.dot
# -rw-rw-r--. 1 ishanu ishanu 1.1M Jul 13  2021  tmptree1.png
# -rw-rw-r--. 1 ishanu ishanu 1.2M Jul 13  2021  tree0.png
# -rw-rw-r--. 1 ishanu ishanu 928K Jul 13  2021  tree1.png
# -rw-rw-r--. 1 ishanu ishanu 482K Jul 13  2021  tree2.png
# -rw-rw-r--. 1 ishanu ishanu  26K Jul 14  2021  Result32.pdf
# -rw-rw-r--. 1 ishanu ishanu  26K Jul 14  2021  Result23.pdf
# -rw-rw-r--. 1 ishanu ishanu  571 Jul 14  2021  roc_new.csv
# -rw-rw-r--. 1 ishanu ishanu  179 Jul 14  2021  roc.csv
# -rw-rw-r--. 1 ishanu ishanu 123K Jul 14  2021  bck_0.ipynb
# drwxrwxr-x. 1 ishanu ishanu  116 Aug  1  2021 'Untitled Folder'
# -rw-rw-r--. 1 ishanu ishanu 244K Jan  9 21:35  combined_bsnip.csv
# -rw-rw-r--. 1 ishanu ishanu 216K Jun 26 12:28  bsnip001-new_multi_classifier_optimization-Copy3.ipynb
# drwxr-xr-x. 1 ishanu ishanu   52 Jun 26 12:28  2022summer
# -rw-rw-r--. 1 ishanu ishanu 2.4K Jun 26 12:28  CAD_.ipynb
# -rw-rw-r--. 1 ishanu ishanu  56K Jun 26 12:28  accvsitemnumber.png
# -rw-rw-r--. 1 ishanu ishanu  52K Jun 26 12:28  accvsitemnumber1.png
# -rw-rw-r--. 1 ishanu ishanu 142K Jun 26 12:28  bsnip001-Copy1_new-b1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 137K Jun 26 12:28  bsnip001-Copy1_new-b2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 138K Jun 26 12:28  bsnip001-Copy1_new-b3.ipynb
# -rw-rw-r--. 1 ishanu ishanu  26K Jun 26 12:28  bsnip001-Copy2_new_CF.ipynb
# -rw-rw-r--. 1 ishanu ishanu 106K Jun 26 12:28  bsnip001-Copy2_new-B3.ipynb
# -rw-rw-r--. 1 ishanu ishanu  92K Jun 26 12:28  bsnip001-Copy2_new_1.ipynb
# -rw-rw-r--. 1 ishanu ishanu  73K Jun 26 12:28  bsnip001-Copy3_new.ipynb
# -rw-rw-r--. 1 ishanu ishanu 110K Jun 26 12:28  bsnip001_updated_L2.pdf
# -rw-rw-r--. 1 ishanu ishanu 109K Jun 26 12:28  bsnip001_updated_L1.pdf
# -rw-rw-r--. 1 ishanu ishanu 214K Jun 26 12:28  bsnip001-new_multi_classifier_optimization.ipynb
# -rw-rw-r--. 1 ishanu ishanu  187 Jun 26 12:28  mean_cf.csv
# -rw-rw-r--. 1 ishanu ishanu 113K Jun 26 12:28  bsnip001_updated_L3.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Jun 26 12:28  updated_bsnip001_L3_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Jun 26 12:28  updated_bsnip001_L2_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu  14K Jun 26 12:28  updated_bsnip001_L1_importances.pdf
# -rw-rw-r--. 1 ishanu ishanu 135K Jun 26 12:28  psycho_orig1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 105K Jun 26 12:28  updatedbsnip001_L3.pdf
# -rw-rw-r--. 1 ishanu ishanu 123K Jun 26 12:28  updatedbsnip001_L1.pdf
# -rw-rw-r--. 1 ishanu ishanu 230K Jun 26 12:38  bsnip001-new_multi_classifier_optimization-Copy2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 216K Jun 26 12:40  bsnip001-new_multi_classifier_optimization-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 104K Jun 26 12:41  bsnip001-new_decision_tree_for_classifiers.ipynb
# -rw-rw-r--. 1 ishanu ishanu  63K Jun 27 00:23  impsummer.png
# -rw-rw-r--. 1 ishanu ishanu  71K Jun 27 00:24  ROCsummer.png
# -rw-rw-r--. 1 ishanu ishanu  60K Jun 27 00:42  accvsnum.png
# -rw-rw-r--. 1 ishanu ishanu 137K Jul  5 16:14  ROC.png
# -rw-rw-r--. 1 ishanu ishanu 542K Jul  5 20:34  model23.mod
# -rw-rw-r--. 1 ishanu ishanu 138K Jul  5 20:34  ROC2vall_3vall_clinical_cognitive.png
# -rw-rw-r--. 1 ishanu ishanu 484K Jul  5 20:43  imp.png
# -rw-rw-r--. 1 ishanu ishanu 700K Jul  5 20:53  imp_small.png
# -rw-rw-r--. 1 ishanu ishanu 5.5K Jul  5 20:58  imp.xls
# -rw-rw-r--. 1 ishanu ishanu  48K Jul  6 12:29  bsnip001-final_stage2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 360K Jul  6 12:31  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage2.ipynb
# -rw-rw-r--. 1 ishanu ishanu 352K Jul  6 12:34  bsnip001-new_multi_classifier_optimization-FINAL_2022_stage2-Copy1.ipynb
# -rw-rw-r--. 1 ishanu ishanu 783K Jul  6 12:36  model123.mod

# %%
# load model
import dill
with open('model123.mod','rb') as f:
    M=dill.load(f)

# %%
def pltROC(M,VAR,ax,FS=14):
    plt.style.use('fivethirtyeight')
    ROC=M[VAR]['rocs']   
    auc=[]
    for key,crv in ROC.items():
        ax.plot(crv['fpr'],crv['tpr'],'.',ms=1,color='b')
        auc=np.append(auc,key)
    ax.set_xlabel('1-specificity',fontsize=FS)
    ax.set_ylabel('sensitivity',fontsize=FS)
    plt.setp(ax.get_xticklabels(), fontsize=FS);
    plt.setp(ax.get_yticklabels(), fontsize=FS);
    ax.set_title(str(VAR)+'-vs-all (AUC: '+ str(auc.mean())[:7]+')' );
    
#plt.style.use('seaborn-whitegrid')
fig=plt.figure(figsize=[15,5])
plt.subplot(1,3,1)
pltROC(M,1,plt.gca(),FS=16)

plt.subplot(1,3,2)
pltROC(M,2,plt.gca(),FS=16)

plt.subplot(1,3,3)
pltROC(M,3,plt.gca(),FS=16)

plt.savefig('ROC12vall_3vall_clinical_cognitive.png',dpi=400,bbox_inches='tight',transparent=True)

# %%
M.keys()
# Out:
# dict_keys([2, 3])

# %%
CF=np.zeros([3,3])
s2=Rs.s1.values[0]
s3=Rs.s2.values[0]
c2=Rs.c1.values[0]
c3=Rs.c2.values[0]
CF=[[c2*c3,1-c2,c2*(1-c3)],[(1-s2)*(1-s3),s2,(1-s2)*s3],[c2*(1-s3),1-c2,c2*s3]]

CF=pd.DataFrame(CF,columns=['B1','B2','B3'])
CF.index=CF.columns
CF
# Out:
#           B1        B2        B3
# B1  0.883600  0.060000  0.056400
# B2  0.036645  0.762036  0.201319
# B3  0.144753  0.060000  0.795247

# %%
IMP1=M[1]['estimator'].feature_importances_
IMP2=M[2]['estimator'].feature_importances_
IMP3=M[3]['estimator'].feature_importances_
plt.style.use('fivethirtyeight')
plt.style.use('ggplot')
IMPdf=pd.DataFrame({'bio3_vs_all':IMP3,'bio2_vs_all':IMP2,'bio1_vs_all':IMP1})


IMPdf.index=feature_names
plt.figure(figsize=[18,4])
ax=IMPdf[IMPdf['bio3_vs_all']>0.005].plot(kind='bar',ax=plt.gca(),width=1)
FS=15
ax.set_xlabel('feature names',fontsize=FS)
ax.set_ylabel('normalized weight',fontsize=FS)
plt.setp(ax.get_xticklabels(), fontsize=FS);
plt.setp(ax.get_yticklabels(), fontsize=FS);
#ax.set_title(str(VAR)+'-vs-all (AUC: '+ str(auc.mean())[:7]+')' );

plt.savefig('imp_small123.png',dpi=400,bbox_inches='tight',transparent=True)

# %%
IMPdf.sort_values('bio3_vs_all',ascending=False)
# Out:
#                                                 bio3_vs_all  bio2_vs_all
# Anti_prop_error_within_Impute_Age_Sex_adjusted     0.207587     0.043450
# panss_n5                                           0.050916     0.016986
# BACS_Verb_Mem_within_imputed                       0.040409     0.006748
# BACS_COMP_Z_within                                 0.037001     0.027324
# BACS_Sym_Cod_z_within_imputed                      0.033622     0.053147
# ...                                                     ...          ...
# panss_n6                                           0.000000     0.016785
# panss_g8                                           0.000000     0.008487
# panss_n2                                           0.000000     0.005129
# Psychosis                                          0.000000     0.000000
# panss_p1                                           0.000000     0.019633
#
# [78 rows x 2 columns]

# %%
i1=IMPdf.sort_values('bio1_vs_all',ascending=False).head(10)
i2=IMPdf.sort_values('bio2_vs_all',ascending=False).head(10)
i3=IMPdf.sort_values('bio3_vs_all',ascending=False).head(10)
if_=pd.DataFrame({'B1_vs_all':i1.index,'B2_vs_all':i2.index,'B3_vs_all':i3.index})
if_.to_excel('imp123.xls')
# Out:
# /tmp/ipykernel_895695/420992951.py:5: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   if_.to_excel('imp123.xls')

# %%
IMPdf.sort_values('bio_3vall',ascending=False).head(10)
# Out:
#                                                 bio_3vall  bio_2vall
# Anti_prop_error_within_Impute_Age_Sex_adjusted   0.207587   0.043450
# panss_n5                                         0.050916   0.016986
# BACS_Verb_Mem_within_imputed                     0.040409   0.006748
# BACS_COMP_Z_within                               0.037001   0.027324
# BACS_Sym_Cod_z_within_imputed                    0.033622   0.053147
# Anti_Corr_Lat_within_Impute_Age_Sex_adjusted     0.031767   0.019904
# SSTProportionError_standwithin                   0.031126   0.050942
# sfs_oetotal                                      0.030792   0.021842
# panss_p3                                         0.025667   0.012908
# young_11                                         0.018375   0.009467

# %%
RES=pd.concat([pd.concat([getRES(df0,MAX_DEPTH=m) for m in tqdm(np.arange(6,12))]) for run in tqdm(range(20))])
# Out:
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:47,  9.42s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.49s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.64s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.77s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.89s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:59<00:00,  9.84s/it]
#   5%|██▏                                         | 1/20 [00:59<18:41, 59.04s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.25s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.41s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.57s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.70s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.90s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:58<00:00,  9.82s/it]
#  10%|████▍                                       | 2/20 [01:57<17:41, 58.99s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:47,  9.46s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.47s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.62s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.82s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:49<00:10, 10.08s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:59<00:00,  9.99s/it]
#  15%|██████▌                                     | 3/20 [02:57<16:50, 59.42s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.37s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.37s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.48s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.68s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.87s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:58<00:00,  9.82s/it]
#  20%|████████▊                                   | 4/20 [03:56<15:47, 59.23s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:47,  9.57s/it]
#  33%|███████████████                              | 2/6 [00:19<00:39,  9.92s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:30, 10.03s/it]
#  67%|██████████████████████████████               | 4/6 [00:39<00:19,  9.99s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:50<00:10, 10.18s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:00<00:00, 10.12s/it]
#  25%|███████████                                 | 5/20 [04:57<14:56, 59.77s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:49,  9.83s/it]
#  33%|███████████████                              | 2/6 [00:19<00:38,  9.70s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:29,  9.90s/it]
#  67%|██████████████████████████████               | 4/6 [00:39<00:19,  9.98s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:49<00:10, 10.07s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:00<00:00, 10.12s/it]
#  30%|█████████████▏                              | 6/20 [05:58<14:01, 60.09s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:10<00:51, 10.30s/it]
#  33%|███████████████                              | 2/6 [00:20<00:39,  9.97s/it]
#  50%|██████████████████████▌                      | 3/6 [00:30<00:29,  9.99s/it]
#  67%|██████████████████████████████               | 4/6 [00:40<00:20, 10.10s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:50<00:10, 10.18s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:01<00:00, 10.20s/it]
#  35%|███████████████▍                            | 7/20 [06:59<13:05, 60.45s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:48,  9.69s/it]
#  33%|███████████████                              | 2/6 [00:19<00:39,  9.82s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:29,  9.72s/it]
#  67%|██████████████████████████████               | 4/6 [00:39<00:19,  9.97s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:49<00:10, 10.03s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:00<00:00, 10.07s/it]
#  40%|█████████████████▌                          | 8/20 [07:59<12:05, 60.44s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:48,  9.78s/it]
#  33%|███████████████                              | 2/6 [00:19<00:39,  9.87s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:29,  9.96s/it]
#  67%|██████████████████████████████               | 4/6 [00:39<00:19,  9.92s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:50<00:10, 10.16s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:01<00:00, 10.22s/it]
#  45%|███████████████████▊                        | 9/20 [09:01<11:07, 60.72s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:47,  9.52s/it]
#  33%|███████████████                              | 2/6 [00:19<00:38,  9.67s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:29,  9.96s/it]
#  67%|██████████████████████████████               | 4/6 [00:39<00:19,  9.89s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:49<00:10, 10.11s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:00<00:00, 10.04s/it]
#  50%|█████████████████████▌                     | 10/20 [10:01<10:05, 60.57s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.23s/it]
#  33%|███████████████                              | 2/6 [00:19<00:38,  9.57s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:29,  9.67s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.71s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.90s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:59<00:00,  9.84s/it]
#  55%|███████████████████████▋                   | 11/20 [11:00<09:00, 60.10s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:47,  9.42s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.49s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.52s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.69s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.89s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:58<00:00,  9.82s/it]
#  60%|█████████████████████████▊                 | 12/20 [11:59<07:57, 59.74s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.31s/it]
#  33%|███████████████                              | 2/6 [00:18<00:38,  9.53s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:29,  9.68s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.70s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.86s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:58<00:00,  9.80s/it]
#  65%|███████████████████████████▉               | 13/20 [12:58<06:56, 59.46s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.31s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.47s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.57s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.79s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.88s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:58<00:00,  9.82s/it]
#  70%|██████████████████████████████             | 14/20 [13:57<05:55, 59.29s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.38s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.47s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.54s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.81s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:49<00:10, 10.08s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:00<00:00, 10.03s/it]
#  75%|████████████████████████████████▎          | 15/20 [14:57<04:57, 59.56s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:47,  9.58s/it]
#  33%|███████████████                              | 2/6 [00:19<00:39,  9.77s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:30, 10.10s/it]
#  67%|██████████████████████████████               | 4/6 [00:40<00:20, 10.15s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:50<00:10, 10.27s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:01<00:00, 10.22s/it]
#  80%|██████████████████████████████████▍        | 16/20 [15:58<04:00, 60.09s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:48,  9.77s/it]
#  33%|███████████████                              | 2/6 [00:19<00:38,  9.63s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:29,  9.89s/it]
#  67%|██████████████████████████████               | 4/6 [00:39<00:20, 10.09s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:50<00:10, 10.21s/it]
# 100%|█████████████████████████████████████████████| 6/6 [01:01<00:00, 10.17s/it]
#  85%|████████████████████████████████████▌      | 17/20 [16:59<03:01, 60.37s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:47,  9.56s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.46s/it]
#  50%|██████████████████████▌                      | 3/6 [00:29<00:29,  9.86s/it]
#  67%|██████████████████████████████               | 4/6 [00:39<00:19,  9.87s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:49<00:09,  9.96s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:59<00:00,  9.95s/it]
#  90%|██████████████████████████████████████▋    | 18/20 [17:59<02:00, 60.18s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.27s/it]
#  33%|███████████████                              | 2/6 [00:18<00:37,  9.41s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.62s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.86s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.86s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:58<00:00,  9.83s/it]
#  95%|████████████████████████████████████████▊  | 19/20 [18:58<00:59, 59.82s/it]
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
#  17%|███████▌                                     | 1/6 [00:09<00:46,  9.25s/it]
#  33%|███████████████                              | 2/6 [00:19<00:38,  9.59s/it]
#  50%|██████████████████████▌                      | 3/6 [00:28<00:28,  9.64s/it]
#  67%|██████████████████████████████               | 4/6 [00:38<00:19,  9.81s/it]
#  83%|█████████████████████████████████████▌       | 5/6 [00:48<00:09,  9.85s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:59<00:00,  9.89s/it]
# 100%|███████████████████████████████████████████| 20/20 [19:57<00:00, 59.89s/it]

# %%
RES
# Out:
#        c1    c2       acc        s1        s2    nq_mean  nq_median
# 444  0.84  0.94  0.688357  0.660147  0.460083  19.865970       20.0
# 589  0.89  0.89  0.726158  0.554013  0.746212  19.078897       19.0
# 709  0.93  0.89  0.764480  0.607077  0.765768  22.942966       23.0
# 620  0.90  0.90  0.785786  0.749043  0.746351  27.610266       28.0
# 743  0.94  0.93  0.827556  0.706084  0.818846  27.729087       28.0
# ..    ...   ...       ...       ...       ...        ...        ...
# 444  0.84  0.94  0.741390  0.739680  0.589142  18.282319       19.0
# 619  0.90  0.89  0.788045  0.725624  0.810812  22.279468       23.0
# 624  0.90  0.94  0.801891  0.729295  0.744376  25.572243       26.0
# 742  0.94  0.92  0.816999  0.775002  0.715631  27.041825       27.0
# 744  0.94  0.94  0.847185  0.768414  0.814229  31.757605       32.0
#
# [120 rows x 7 columns]

# %%
RES.set_index('nq_median').acc.plot(style='ko')
# Out:
# <AxesSubplot:xlabel='nq_median'>

# %%
ax=sns.regplot(x=RES.nq_mean,y=RES.acc,ci=99.999,lowess=True)
ax.set_xlabel('mean number of items')
ax.set_ylabel('mean accuracy')
#plt.savefig('accvsitemnumber.png',dpi=200,bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'mean accuracy')

# %%
plt.style.use('fivethirtyeight')
df=pd.DataFrame(RES.set_index('nq_mean').acc)
import scipy.stats as stats
import statsmodels.api as sm
from scipy import interpolate
from scipy.interpolate import interp1d

lowess = sm.nonparametric.lowess
df.index=df.index.astype(float)
df=df.sort_index()
S=.2
RUNS=50
DF=df
   
for i in range(RUNS):
    X=df.sample(int(np.round(S*df.index.size))).sort_index().reset_index().values

    z = lowess(X[:,1], X[:,0], frac= .25)
    f = interp1d(z[:,0], z[:,1])
    Y=f(X[:,0])
    DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
DF=DF.interpolate(method='index',order=3,limit_direction='both')
STD=pd.DataFrame(2.62*(DF.std(axis=1)/np.sqrt(RUNS)))
Mf=pd.DataFrame(DF.mean(axis=1)).assign(sm=STD)
Mf.columns=['mn','sm']
ax=Mf.mn.plot()
plt.fill_between(Mf.index,Mf.mn-Mf.sm,Mf.mn+Mf.sm,alpha=.35)
ax.set_xlabel('mean number of items')
ax.set_ylabel('mean accuracy')
#plt.savefig('accvsitemnumber1.png',dpi=200,bbox_inches='tight',transparent=True)
# Out:
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/3830656434.py:21: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# Text(0, 0.5, 'mean accuracy')

# %%
df=pd.DataFrame(RES.set_index('nq_median').acc)
import scipy.stats as stats
import statsmodels.api as sm
from scipy import interpolate
from scipy.interpolate import interp1d

lowess = sm.nonparametric.lowess
df.index=df.index.astype(float)
df=df.sort_index()
S=.3
RUNS=8
DF=df

for i in range(RUNS):
    X=df.sample(int(np.round(S*df.index.size))).sort_index().reset_index().values

    z = lowess(X[:,1], X[:,0], frac= .35)
    f = interp1d(z[:,0], z[:,1])
    Y=f(X[:,0])
    DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
DF=DF.interpolate(method='index',order=3,limit_direction='both')
STD=pd.DataFrame(2.62*(DF.std(axis=1)/np.sqrt(RUNS)))
Mf=pd.DataFrame(DF.mean(axis=1)).assign(sm=STD)
Mf.columns=['mn','sm']
ax=Mf.mn.plot()
plt.fill_between(Mf.index,Mf.mn-Mf.sm,Mf.mn+Mf.sm,alpha=.5)
ax.set_xlabel('mean number of items')
ax.set_ylabel('mean accuracy')
# Out:
# /tmp/ipykernel_1650491/2545937345.py:20: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/2545937345.py:20: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# /tmp/ipykernel_1650491/2545937345.py:20: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0'} in the result is deprecated and will raise a MergeError in a future version.
#   DF=DF.join(pd.DataFrame(Y,X[:,0]),rsuffix=str(i))
# Text(0, 0.5, 'mean accuracy')

# %%
R=RES.sort_values('acc',ascending=False)['c1','c2','acc']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('c1', 'c2', 'acc')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1650491/243982563.py in <module>
# ----> 1 R=RES.sort_values('acc',ascending=False)['c1','c2','acc']
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('c1', 'c2', 'acc')

# %%
R_=R.pivot(index='c2',columns='c3')
R_

# %%
ax=sns.heatmap(R_)
ax.set_xlabel('c-2vall')
ax.set_ylabel('c-3vall')

# %%
pos=plt.imshow(R_)
plt.colorbar(pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-832dbe95c404> in <module>
# ----> 1 pos=plt.imshow(R_)
#       2 plt.colorbar(pos)
#
# NameError: name 'R_' is not defined

# %%
R_=R.pivot(index='c1',columns='c2')
R_.columns=[str(x[1])[:4] for x in R_.columns]
R_.index=[str(x)[:4] for x in R_.columns]

# %%
getacc(.85,.8,p1,p2,p3,f1,f2)

# %%
ACC=[]
CLFh={}
for run in tqdm(np.arange(500)):
    auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    ACC=np.append(ACC,auc)
    if auc > 0.5:
        CLFh[auc]=CLFS
CLFstarA=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
f1=getFmap(CLFstarA)


#df=df0[df0.Biotype.isin([1,5])]
df=df0
X=df.iloc[:,2:].values
y=df.Biotype.values#.astype(str)
y=[(int(x)==3)+0 for x in y ]

ACC=[]
CLFh={}
for run in tqdm(np.arange(500)):
    auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    ACC=np.append(ACC,auc)
    if auc > 0.5:
        CLFh[auc]=CLFS
CLFstarB=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
f2=getFmap(CLFstarB)

# %%
f2=getFmap(CLFstarB)

# %%
CLFstarB=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
#F=[]
#for i in CLFstar.estimators_:
#    F=np.append(F,i.tree_.feature)
#uF=np.array(list(set(list(F[F>0]))))
#len(uF)

# %%
ACC=[]
CLFh={}
for run in tqdm(np.arange(500)):
    auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=MAX_DEPTH,n_estimators=NUMESTIMATORS,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    ACC=np.append(ACC,auc)
    if auc > 0.5:
        CLFh[auc]=CLFS
sns.distplot(ACC)
np.median(ACC)

# %%
#df=df0[df0.Biotype.isin([1,5])]
df=df0
X=df.iloc[:,2:].values
y=df.Biotype.values#.astype(str)
y=[(int(x)==3)+0 for x in y ]

# %%
f1=getFmap(CLFstarA)

# %%
CLFstarA=CLFh[np.array([k for k in CLFh.keys()]).max()][0]
