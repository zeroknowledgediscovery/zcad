# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from scipy.spatial import ConvexHull
from tqdm import tqdm
import random
plt.style.use('ggplot')
import pickle
from sklearn import tree
from sklearn.tree import export_graphviz
from joblib import dump, load
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
# %matplotlib inline

# %%
def getAuc(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,FPR=[],TPR=[],VERBOSE=False, USE_ONLY=None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit),
                RandomForestClassifier(n_estimators=n_estimators,
                                       max_depth=max_depth,min_samples_split=minsplit),
                ExtraTreesClassifier(n_estimators=n_estimators,
                                     max_depth=max_depth,min_samples_split=minsplit),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict_proba(X_test)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        auc=metrics.auc(fpr, tpr)
        if VERBOSE:
            print(auc)

        FPR=np.append(FPR,fpr)
        TPR=np.append(TPR,tpr)
    points=np.array([[a[0],a[1]] for a in zip(FPR,TPR)])
    hull = ConvexHull(points)
    x=np.argsort(points[hull.vertices,:][:,0])
    auc=metrics.auc(points[hull.vertices,:][x,0],points[hull.vertices,:][x,1])
    return auc,CLASSIFIERS

# %%
def getConfusion(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,CONFUSION={},VERBOSE=False, USE_ONLY=None,target_names = None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit),
                RandomForestClassifier(n_estimators=n_estimators,class_weight='balanced',
                                       max_depth=max_depth,min_samples_split=minsplit),
                ExtraTreesClassifier(n_estimators=n_estimators,class_weight='balanced',
                                     max_depth=max_depth,min_samples_split=minsplit),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict(X_test)
        #print(y_test,y_pred)
        cmat=confusion_matrix(y_test, y_pred)
        acc=accuracy_score(y_test, y_pred)
        
        CONFUSION[clf]=cmat
        
        if VERBOSE:
            print(classification_report(y_test, y_pred, target_names=target_names))
            print('Confusion MAtrix:\n', cmat)
            print(' ')
            print('Accuracy:', acc)

        
    return CONFUSION,acc

# %%
df=pd.read_csv('PSYCHO.DAT',header=None,index_col=0,sep='\s+')
df=df[df[1]>0]
X=df.loc[:,2:].values
y=df.loc[:,1].values.astype(str)

# %%
ACC=[]
for run in tqdm(np.arange(400)):
    CONF,acc=getConfusion(X,y,test_size=0.3,max_depth=None,n_estimators=2,
               minsplit=4,VERBOSE=False, USE_ONLY=[1],target_names=['schizophrenic',
                                                                   'schizoaffective',
                                                                   'depressed',
                                                                   'bipolar'])
    ACC=np.append(ACC,acc)

sns.distplot(ACC)
# Out:
# 100%|██████████| 400/400 [00:02<00:00, 139.19it/s]

# %%
df=pd.read_csv('PSYCHO.DAT',header=None,index_col=0,sep='\s+')
df=df[df[1]>0]
X=df.loc[:,2:].values
y=df.loc[:,1].values.astype(str)

df=pd.read_csv('/home/ishanu/Dropbox/scratch_/Qfeatures.csv')
df=df[df.labels>0]
X1=df.drop('labels',axis=1).values
y=df.labels.values.astype(str)
X=np.c_[X,X1]
X=X1

# %%
qACC=[]
for run in tqdm(np.arange(400)):
    CONF,acc=getConfusion(X,y,test_size=0.3,max_depth=10,n_estimators=2,
               minsplit=3,VERBOSE=False, USE_ONLY=[2],target_names=['schizophrenic',
                                                                   'schizoaffective',
                                                                   'depressed',
                                                                   'bipolar'])
    qACC=np.append(qACC,acc)

ax=sns.distplot(ACC)
sns.distplot(qACC,ax=ax)
# Out:
# 100%|██████████| 400/400 [00:02<00:00, 175.91it/s]

# %%
CONF
# Out:
# {RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[189,  73,  54,   4],
#         [ 12,   8,   7,   0],
#         [  9,   1,  20,   0],
#         [  4,   0,   3,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[225,  18,  66,  17],
#         [ 14,   4,   4,   1],
#         [  3,   5,  19,   2],
#         [  1,   0,   6,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[ 86, 114, 102,  29],
#         [  4,  12,   7,   1],
#         [  0,   6,   6,  14],
#         [  0,   4,   0,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[246,  37,  19,  13],
#         [ 20,   2,   3,   1],
#         [ 17,   1,  19,   0],
#         [  3,   0,   5,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[150,  90,  75,   8],
#         [  7,   9,   4,   1],
#         [  3,   3,  26,   0],
#         [  1,   0,   5,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[149,  91,  38,  38],
#         [ 15,   7,   3,   4],
#         [ 13,   1,  16,   3],
#         [  0,   0,   6,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[166,  75,  75,   1],
#         [ 13,   8,   6,   0],
#         [  3,   3,  26,   0],
#         [  3,   0,   6,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[220,  32,  47,  24],
#         [ 17,   1,   3,   3],
#         [ 10,   0,  21,   0],
#         [  0,   0,   4,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[130,   9, 157,  19],
#         [ 15,   1,   7,   2],
#         [  7,   0,  27,   1],
#         [  0,   0,   6,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[202,  65,  31,  19],
#         [ 12,   8,   1,   5],
#         [ 14,   5,   1,  15],
#         [  2,   1,   0,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[186,  78,  43,  12],
#         [ 11,  10,   2,   2],
#         [ 13,   1,  19,   1],
#         [  3,   1,   4,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[184,  77,  33,  19],
#         [ 10,  13,   1,   1],
#         [ 12,   1,  24,   0],
#         [  2,   3,   7,   0]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[146, 109,  58,   8],
#         [ 11,  10,   2,   1],
#         [  4,   2,  23,   0],
#         [  4,   0,   7,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[199,  62,  32,  25],
#         [ 13,  11,   2,   1],
#         [ 11,   1,  16,   3],
#         [  1,   0,   5,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[199,  49,  71,   3],
#         [ 13,   5,   7,   0],
#         [  5,   2,  23,   0],
#         [  0,   5,   5,   0]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[255,  25,  34,   2],
#         [ 23,   0,   3,   3],
#         [ 12,   0,  20,   0],
#         [  2,   0,   4,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[226,  31,  19,  38],
#         [ 18,   6,   0,   4],
#         [  7,   3,   4,  19],
#         [  1,   6,   0,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[215,  70,  36,   6],
#         [ 11,   6,   2,   3],
#         [ 10,   0,  20,   0],
#         [  1,   0,   2,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[179,  57,  81,   5],
#         [ 16,   5,   4,   2],
#         [  6,   2,  18,   0],
#         [  3,   0,   7,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[159,  97,  47,  13],
#         [ 11,   8,   6,   0],
#         [  5,   5,  25,   5],
#         [  2,   0,   3,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[171,  67,  66,  16],
#         [ 13,   9,   1,   2],
#         [  8,   1,   7,  16],
#         [  1,   3,   0,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[207,  20,  69,  10],
#         [ 29,   2,   4,   1],
#         [  4,   0,  31,   0],
#         [  1,   0,   5,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[197,  34,  80,   7],
#         [ 11,   3,   6,   3],
#         [  4,   0,  26,   4],
#         [  2,   0,   8,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[216,  48,  52,   0],
#         [ 14,   6,   4,   1],
#         [ 10,   2,  21,   0],
#         [  1,   2,   7,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[162,  81,  74,   2],
#         [  7,   8,   7,   0],
#         [  3,   2,  27,   0],
#         [  4,   0,   8,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[203,  65,  40,  13],
#         [ 13,   5,   3,   1],
#         [ 10,   2,  22,   0],
#         [  1,   2,   4,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[209,  34,  50,  16],
#         [ 20,   2,   5,   1],
#         [  8,   1,  31,   0],
#         [  1,   1,   5,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[229,  60,  11,  20],
#         [ 18,   3,   0,   3],
#         [  9,   3,   1,  19],
#         [  2,   1,   0,   8]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[149, 119,  33,  21],
#         [ 12,  11,   1,   1],
#         [  2,   8,  15,   3],
#         [  2,   0,   5,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[177,  86,  29,  31],
#         [  7,  12,   1,   2],
#         [  7,   8,  17,   3],
#         [  0,   0,   3,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[163,  87,  59,  12],
#         [ 12,   6,   3,   1],
#         [  3,   3,  24,   4],
#         [  1,   1,   3,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[180,  77,  45,  16],
#         [ 12,   7,   2,   4],
#         [  4,   1,  11,  20],
#         [  3,   3,   0,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[119, 145,  36,  14],
#         [  7,  14,   5,   0],
#         [  5,  15,  17,   2],
#         [  1,   0,   5,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[217,  61,   7,  34],
#         [ 18,   4,   0,   4],
#         [ 15,   0,   1,  19],
#         [  1,   0,   0,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[190,  40,  82,   7],
#         [ 16,   2,   5,   2],
#         [  2,   0,  29,   0],
#         [  1,   4,   4,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[227,  40,  23,  23],
#         [ 17,   2,   1,   4],
#         [ 14,   2,  18,   2],
#         [  4,   1,   6,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[ 87, 108,  97,  34],
#         [  8,   7,   2,   1],
#         [  2,   5,  22,   4],
#         [  0,   0,   7,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[149,  81,  81,   9],
#         [ 14,   6,   5,   1],
#         [  8,   3,  21,   1],
#         [  0,   2,   4,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[143,  91,  83,   2],
#         [ 13,   7,   6,   2],
#         [  3,   4,  23,   0],
#         [  2,   0,   5,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[182,  46,  82,  10],
#         [ 11,   2,  12,   1],
#         [  6,   4,  24,   0],
#         [  1,   1,   4,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[199,  70,  30,  20],
#         [ 13,   7,   2,   4],
#         [  9,   1,   2,  20],
#         [  3,   0,   0,   7]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[135, 103,  71,  13],
#         [  8,  13,   2,   3],
#         [  5,   3,  24,   0],
#         [  0,   0,   3,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[155,  63,  96,  10],
#         [  8,   4,  10,   1],
#         [  1,   0,  27,   1],
#         [  2,   0,   7,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[254,  50,  12,   8],
#         [ 19,   3,   2,   1],
#         [ 18,   0,  11,   1],
#         [  2,   0,   5,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[214,  54,  22,  26],
#         [ 17,   5,   1,   3],
#         [ 13,   2,  13,   9],
#         [  0,   2,   3,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[237,  42,  27,   2],
#         [ 16,   6,   3,   1],
#         [ 13,   1,  24,   0],
#         [  4,   0,   9,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[108,  68, 133,  11],
#         [  9,   7,  10,   1],
#         [  0,   3,  27,   0],
#         [  2,   3,   5,   0]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[203,  17,  92,   3],
#         [ 15,   3,   9,   3],
#         [  7,   0,  25,   0],
#         [  1,   0,   4,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[164,  44,  97,  17],
#         [ 15,   5,   3,   4],
#         [  6,   0,  22,   1],
#         [  1,   0,   5,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[230,  39,  47,   5],
#         [ 20,   5,   1,   1],
#         [  9,   2,  17,   0],
#         [  1,   2,   4,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[161,  50,  89,  13],
#         [ 14,   3,   5,   3],
#         [  6,   1,  29,   1],
#         [  0,   0,   5,   7]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[224,  45,  13,  29],
#         [ 17,   8,   3,   5],
#         [  9,   3,   6,  16],
#         [  3,   0,   0,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[220,  50,  43,  12],
#         [ 14,   4,   2,   3],
#         [  8,   5,  17,   1],
#         [  1,   1,   4,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[ 94, 135,  58,  37],
#         [  3,  16,   4,   3],
#         [  5,   1,  20,   4],
#         [  2,   1,   3,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[185,  67,  45,  19],
#         [ 11,  13,   3,   1],
#         [ 13,   0,  20,   0],
#         [  1,   0,   8,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[186,  50,  50,  29],
#         [ 22,   0,   2,   2],
#         [  6,   1,  10,  17],
#         [  5,   3,   0,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[216,  35,  39,  27],
#         [ 16,   5,   0,   5],
#         [  3,   1,   8,  19],
#         [  4,   0,   0,   9]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[194,  82,  14,  31],
#         [ 12,   6,   0,   5],
#         [ 12,   2,   1,  20],
#         [  0,   1,   1,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[161, 111,  34,   7],
#         [  8,  11,   4,   3],
#         [  4,  15,  17,   0],
#         [  3,   1,   6,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[209,  37,  55,  19],
#         [ 15,   7,   4,   2],
#         [ 14,   0,  16,   1],
#         [  0,   0,   6,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[201,  32,  61,  18],
#         [ 20,   4,   2,   3],
#         [ 14,   0,  21,   1],
#         [  0,   0,   5,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[197,  79,  36,   8],
#         [ 17,   5,   3,   1],
#         [  3,  10,  17,   2],
#         [  3,   0,   3,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[172, 103,  33,  11],
#         [ 11,  11,   1,   1],
#         [ 11,   8,  14,   1],
#         [  1,   0,   6,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[186,  62,  40,  22],
#         [ 15,   7,   1,   4],
#         [  1,  11,  15,  10],
#         [  7,   0,   3,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[172,  92,  32,  22],
#         [ 14,   6,   2,   2],
#         [ 12,   1,  20,   1],
#         [  1,   0,   5,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[222,  27,  31,  32],
#         [ 21,   1,   2,   3],
#         [  1,   2,   9,  21],
#         [  5,   1,   0,   9]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[168,  61,  84,   5],
#         [ 13,   8,   6,   0],
#         [  3,   3,  25,   0],
#         [  0,   0,   8,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[ 99, 120,  86,  10],
#         [  5,  11,   6,   2],
#         [  3,   4,   9,  21],
#         [  4,   5,   0,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[206,  51,  36,  24],
#         [ 13,   5,   4,   1],
#         [  7,   0,  22,   7],
#         [  2,   1,   4,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[ 43,  61, 161,  49],
#         [  6,   5,  10,  10],
#         [  0,   1,  26,   3],
#         [  0,   0,   6,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[161,  94,  47,  19],
#         [  6,  12,   2,   2],
#         [  9,   0,  25,   0],
#         [  1,   0,   6,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[168,  79,  26,  44],
#         [ 19,   5,   3,   1],
#         [  6,   1,   7,  17],
#         [  3,   4,   0,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[159,  44, 100,  12],
#         [ 13,   8,   7,   1],
#         [  5,   0,  29,   1],
#         [  1,   0,   3,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[215,   4,  59,  31],
#         [ 24,   2,   6,   1],
#         [  7,   0,  20,   7],
#         [  1,   0,   5,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[167,  93,  50,   7],
#         [ 13,  10,   3,   2],
#         [ 14,   1,  13,   4],
#         [  0,   1,   5,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[176,  77,  26,  48],
#         [ 11,   6,   0,   4],
#         [ 13,   1,   7,   8],
#         [  1,   0,   2,   7]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[218,  38,  55,  10],
#         [ 17,   4,   5,   1],
#         [  3,   2,  21,   1],
#         [  3,   0,   5,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[170,  53,  98,   4],
#         [ 14,   6,   2,   2],
#         [  3,   2,  25,   0],
#         [  1,   0,   3,   4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[195,  46,  65,  20],
#         [ 13,   4,   2,   0],
#         [  8,   3,  21,   1],
#         [  2,   0,   4,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[196,  40,  72,   6],
#         [ 21,   0,   6,   2],
#         [  2,   1,  32,   0],
#         [  1,   0,   6,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[174,  96,  39,   7],
#         [ 12,   6,   3,   0],
#         [  9,   7,  21,   3],
#         [  2,   0,   3,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[115,  44, 140,  20],
#         [  3,   7,  11,   1],
#         [  2,   0,  30,   1],
#         [  0,   0,   7,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[129,  81,  95,  16],
#         [ 10,   7,   6,   3],
#         [  0,   4,  23,   1],
#         [  3,   0,   4,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[228,  27,  45,  13],
#         [ 17,   5,   2,   3],
#         [ 13,   1,  20,   3],
#         [  1,   0,   3,   6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[ 91, 152,  77,   3],
#         [  6,   8,   5,   2],
#         [  6,   1,  23,   1],
#         [  3,   1,   5,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[ 69, 151,  44,  56],
#         [  3,  17,   4,   1],
#         [  2,  11,  18,   1],
#         [  0,   5,   3,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
# ...
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[90, 38, 20,  9],
#         [ 7, 10,  1,  2],
#         [ 2,  1,  3,  4],
#         [ 1,  0,  1,  5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[107,  37,   7,  16],
#         [  4,   4,   0,   3],
#         [  7,   0,   4,   2],
#         [  0,   0,   0,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[81, 34, 30,  2],
#         [ 4,  2,  6,  1],
#         [ 6,  2, 16,  0],
#         [ 1,  0,  7,  2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[85, 36, 16, 11],
#         [ 7,  6,  2,  2],
#         [ 4,  0, 15,  3],
#         [ 1,  1,  2,  3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[111,  13,  16,  21],
#         [  7,   1,   2,   2],
#         [  6,   2,   6,   2],
#         [  0,   0,   4,   1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[99, 19, 27, 16],
#         [ 9,  4,  1,  1],
#         [ 4,  0,  9,  3],
#         [ 0,  0,  1,  1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[61, 53, 29, 17],
#         [ 5,  5,  2,  1],
#         [ 2,  1, 12,  0],
#         [ 0,  0,  5,  1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[95, 24, 30, 10],
#         [ 5,  6,  1,  2],
#         [ 3,  2,  9,  1],
#         [ 0,  1,  3,  2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[76, 24, 50,  1],
#         [ 7,  3,  2,  0],
#         [ 1,  0, 20,  0],
#         [ 0,  4,  5,  1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[59, 64, 33,  5],
#         [ 6,  4,  4,  1],
#         [ 1,  1,  9,  1],
#         [ 1,  0,  3,  2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[44, 56, 43, 13],
#         [ 4,  4,  3,  0],
#         [ 3,  1, 17,  1],
#         [ 0,  0,  4,  1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[117,  19,  18,   4],
#         [  7,   2,   2,   3],
#         [  4,   2,   7,   0],
#         [  0,   0,   6,   3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[78, 53, 26, 11],
#         [ 9,  1,  1,  0],
#         [ 1,  0,  9,  0],
#         [ 0,  0,  2,  3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[101,  20,  18,  16],
#         [  8,   4,   0,   0],
#         [  5,   0,   6,   8],
#         [  1,   0,   2,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[105,  22,  30,   5],
#         [  7,   4,   1,   0],
#         [  2,   2,   7,   3],
#         [  3,   0,   1,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[93, 28, 15, 17],
#         [12,  4,  0,  1],
#         [ 5,  1,  6,  5],
#         [ 1,  0,  4,  2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[88, 41, 32,  7],
#         [ 5,  2,  1,  0],
#         [ 3,  1, 10,  2],
#         [ 0,  0,  1,  1]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[91, 35, 11, 19],
#         [ 8,  3,  2,  2],
#         [ 8,  0,  9,  2],
#         [ 0,  0,  4,  0]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[115,  19,  20,  12],
#         [  5,   2,   1,   1],
#         [  4,   1,   8,   2],
#         [  0,   0,   4,   0]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[89, 46, 24,  1],
#         [ 3,  6,  4,  1],
#         [ 2,  7,  6,  0],
#         [ 1,  0,  4,  0]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[61, 56, 19, 19],
#         [ 5,  7,  0,  2],
#         [ 0,  1,  9,  8],
#         [ 0,  0,  3,  4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[81, 57, 30,  0],
#         [ 4,  3,  0,  2],
#         [ 1,  1, 10,  0],
#         [ 1,  0,  1,  3]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[63, 64, 21, 11],
#         [ 4,  8,  2,  1],
#         [ 4,  0,  2,  8],
#         [ 0,  0,  0,  6]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[120,  23,  24,   3],
#         [  4,   2,   3,   2],
#         [  3,   0,   7,   0],
#         [  1,   0,   0,   2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[88, 16, 45, 11],
#         [ 5,  4,  3,  0],
#         [ 1,  0, 13,  1],
#         [ 0,  0,  3,  4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[74, 20, 43, 21],
#         [ 7,  5,  0,  2],
#         [ 2,  0,  4, 11],
#         [ 0,  1,  0,  4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[115,  29,   6,  18],
#         [  5,   2,   0,   2],
#         [  3,   0,   2,   4],
#         [  1,   1,   1,   5]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[58, 48, 36, 18],
#         [ 3,  5,  1,  1],
#         [ 0,  2,  7,  9],
#         [ 0,  0,  2,  4]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[84, 29, 33, 12],
#         [ 7,  5,  2,  1],
#         [ 6,  1,  7,  4],
#         [ 1,  0,  0,  2]]),
#  RandomForestClassifier(bootstrap=True, class_weight='balanced',
#              criterion='gini', max_depth=3, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=4, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False,
#              random_state=None, verbose=0, warm_start=False): array([[93, 25, 35,  5],
#         [ 4,  3,  3,  1],
#         [ 2,  1, 10,  6],
#         [ 0,  1,  3,  2]]),
#  ...}
