# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from scipy.spatial import ConvexHull
from tqdm import tqdm
import random
plt.style.use('ggplot')
import pickle
from sklearn import tree
from sklearn.tree import export_graphviz
from joblib import dump, load
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from scipy.interpolate import interp1d
# %matplotlib inline

# %%
def getAuc(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,FPR=[],TPR=[],VERBOSE=False, USE_ONLY=None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit,class_weight='balanced'),
                RandomForestClassifier(n_estimators=n_estimators,
                                       max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                ExtraTreesClassifier(n_estimators=n_estimators,
                                     max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict_proba(X_test)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        auc=metrics.auc(fpr, tpr)
        if VERBOSE:
            print(auc)

        FPR=np.append(FPR,fpr)
        TPR=np.append(TPR,tpr)
    points=np.array([[a[0],a[1]] for a in zip(FPR,TPR)])
    hull = ConvexHull(points)
    x=np.argsort(points[hull.vertices,:][:,0])
    auc=metrics.auc(points[hull.vertices,:][x,0],points[hull.vertices,:][x,1])
    return auc,CLASSIFIERS


def saveFIG(filename='tmp.pdf',AXIS=False):
    '''
        save fig for publication
    '''
    import pylab as plt
    plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
    plt.margins(0,0)
    if not AXIS:
        plt.gca().xaxis.set_major_locator(plt.NullLocator())
        plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig(filename,dpi=300, bbox_inches = 'tight',
                pad_inches = 0,transparent=False) 
    return

# %%
df=pd.read_csv('psychoByDiag.csv',index_col=0,sep=',')

# %%
df=df[df['DX']>0]

#df=df[df.DX.between(1,2)]

X=df.iloc[:,1:].values
y=df.iloc[:,0].values.astype(str)
#y=[(x=='1')+0 for x in y]

y=[(int(x)<3)+0 for x in y ]

Xdiag=X

# %%
Xdiag.shape
# Out:
# (644, 5)

# %%
ACC=[]
CLFdiag=None
for run in tqdm(np.arange(500)):
    auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=6,n_estimators=2,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    ACC=np.append(ACC,auc)
    if auc > 0.85:
        CLFdiag=CLFS
sns.distplot(ACC)
np.median(ACC)
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 234.65it/s]
# 0.8443302387267904

# %%
df=pd.read_csv('PSYCHO.DAT',header=None,index_col=0,sep='\s+')
df=df[df[1]>0]
#df=df[df[1].between(1,2)]

X=df.loc[:,2:].values
#y=df.loc[:,1].values.astype(str)
#y=(df.loc[:,1]==1)+0
y=[(df.loc[:,1]<3)+0 for x in y ]

Xpsy=X

# %%
df=pd.read_csv('/home/ishanu/Dropbox/scratch_/Qfeatures.csv')
df=df[df.labels>0]

#df=df[df.labels.between(1,2)]

Xq=df.drop('labels',axis=1).values
#y=df.labels.values.astype(str)
X=np.c_[Xpsy,Xq]
#X=Xpsy
#X=np.c_[X,Xdiag]
#X=np.c_[Xpsy,Xdiag]
#X=X1
#X=np.c_[Xpsy,Xdiag]

# %%
y=(df.labels<3)+0

# %%
X.shape
# Out:
# (644, 83)

# %%
qACC=[]
CLF={}
for run in tqdm(np.arange(2000)):
    auc,CLFS=getAuc(X,y,test_size=0.6,max_depth=6,n_estimators=2,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    qACC=np.append(qACC,auc)
    if auc > 0.8:
        CLF[auc]=CLFS
        #print('.')
ax=sns.distplot(ACC,label='noq')
sns.distplot(qACC,ax=ax,label='Q')
ax.legend()
np.median(qACC)
CLF
# Out:
# 100%|██████████| 2000/2000 [00:09<00:00, 217.81it/s]
# {0.8181269793394661: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.859636555572312: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8273229369720597: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.831492895052217: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8150811209439528: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8076272381220921: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.9179328901551125: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8102628285356697: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8177866195107574: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8220597790773229: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8939537828426718: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8744956772334294: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8046028305495345: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8204610951008645: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8115226610124568: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8616816856612776: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8162692847124825: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8963616714697406: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8604479811376363: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8727846487313528: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8191865605658709: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8179083288263926: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8719948018193632: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8265700483091789: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8684792219274977: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8866023166023167: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8377881844380404: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.9014409221902018: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8476866883116885: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8246913580246914: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8802702702702703: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8522779922779923: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8247481830932041: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8092928660826032: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8376543209876544: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8929142084562438: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8307798481711526: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8517441860465116: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8571863169280692: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8475308641975308: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8536232905681658: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8804524020041261: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8318083573487032: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.9013677518782508: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8304314112505288: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8439613526570049: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.891062481579723: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8726208938389962: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8390206732043468: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8224249736088072: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8564717553688141: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8635749053542456: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8824016563146999: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8909356725146198: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.832665832290363: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8342084942084942: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8252009184845006: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8846181556195966: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8935217820386296: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8172700296735905: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8953066332916145: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8005681818181818: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.876176948051948: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8273775216138328: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8717348927875244: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8177712800519819: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8433494193937566: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8618702553485162: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.84736958443855: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.848560700876095: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8546454250669675: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.861817198485668: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8312284334023464: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8204247104247104: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8405797101449275: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.863840155945419: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8366883116883117: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8828470380194517: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8851332299450163: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8013454317897373: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8972079502433749: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8382040050062578: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8682276657060519: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8521402067320434: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8402225169466548: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8269599174771589: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8994989684644858: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.865007012622721: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8366377661609078: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8530536784393727: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8680714889506098: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.9007936507936509: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8558661145617668: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
# ...
#  0.8663738524849636: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8737487663893979: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8481645905115293: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8304843304843305: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8478605935127673: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8530068832266634: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8649615690432017: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.9055459846276174: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.849545159194282: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8308488612836439: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8961701563742379: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8201075744179193: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8641995759342698: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8348437960506927: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8783890845070422: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8791660383049316: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8488710113574905: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8292664092664093: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8216913946587537: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.861800366558579: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.852493660185968: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8839918564319108: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8617871189773845: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8495366795366796: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8171299247736836: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.883078691184424: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8539075175770688: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8506528189910979: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.9023685323558438: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.8765432098765433: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  0.89710433244916: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)],
#  ...}

# %%
CLFstar=CLF[np.array([k for k in CLF.keys()]).max()][0]

# %%
#calculating average number of items
XC={}
LS=[]
count=0
for (auc,clf) in CLF.items():
        XC[count]=getCoverage(clf,verbose=False)
        LS=np.append(LS,len(XC[count]))
        count=count+1
len(list(set(LS)))
# Out:
# 29

# %%
#calculating average number of items
COV=[]
for (auc,clf) in CLF.items():
        COV.extend([auc,len(getCoverage(clf,verbose=False))])
COV=np.array(COV).reshape(int(len(COV)/2),2)
CF=pd.DataFrame(COV,columns=['auc','num'])

A=CF.num.mean()
#A=(A/63)*12

CF['numt']=CF.num*(12/63.)
CF.to_csv('nitems_SSvO.csv')
print(A)
# Out:
# 27.128389596015495

# %%
auc_=[]
ROC={}
fpr_ = np.linspace(0, 1, num=20, endpoint=True)
for run in np.arange(1000):
    clf=CLFstar
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    y_pred=clf.predict_proba(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
    f = interp1d(fpr, tpr)
    auc_=np.append(auc_,metrics.auc(fpr_, f(fpr_)))
    ROC[metrics.auc(fpr, tpr)]={'fpr':fpr_,'tpr':f(fpr_)}
sns.distplot(auc_)
auc_.mean()
# Out:
# 0.9489318361568626

# %%
TPR=[]
for a in ROC.keys():
    #print(a)
    #break
    plt.plot(ROC[a]['fpr'],ROC[a]['tpr'],'-k',alpha=.05)
    TPR=np.append(TPR,ROC[a]['tpr'])
TPR=TPR.reshape(int(len(TPR)/len(fpr_)),len(fpr_))
plt.plot(fpr_,np.median(TPR,axis=0),'-r')
metrics.auc(fpr_,np.median(TPR,axis=0))
plt.gca().set_title('schizophrenia + scheff vs others')
plt.text(.6,.65,'AUC: '+str(metrics.auc(fpr_,np.median(TPR,axis=0)))[:5],color='r')
#plt.text(.6,.31,'AUC: '+str(metrics.auc(fpr_,np.median(tprA,axis=0)))[:5],color='b')
#plt.text(.6,.19,'AUC: '+str(metrics.auc(fpr_,np.median(tprB,axis=0)))[:5],color='g')
plt.gca().set_xlabel('1-specificity')
plt.gca().set_ylabel('sensitivity')
saveFIG('sczsceff.pdf',AXIS=True)

# %%
# confidence bound calculations
from scipy import interpolate
import subprocess
from sklearn import metrics

xnew = np.arange(0.01, 1, 0.01)

Y=[]
for a in ROC.keys():
    #print(a)
    #break
    x=ROC[a]['fpr']
    y=ROC[a]['tpr']
    f = interpolate.interp1d(x, y)
    ynew = f(xnew)
    Y=np.append(Y,ynew)
    #plt.plot(x, y, 'o', xnew, ynew, '-')
    #break
Y=pd.DataFrame(Y.reshape(int(len(Y)/len(xnew)),len(xnew))).sample(20).transpose()
Y.to_csv('Y.csv',index=None,header=None,sep=' ')
T=0.99

CNFBD="~/ZED/Research/data_science_/bin/cnfbd "
subprocess.call(CNFBD+" -N 5  -f Y.csv -a "+str(T)+" > Y.dat ", shell=True)
Yb=pd.read_csv('Y.dat',header=None,sep=' ',names=['lb','mn','ub'])
Yb['fpr']=xnew[:len(Yb.lb.values)]
if len(Yb.lb.values) < len(xnew):
    Yb=pd.concat([Yb,pd.DataFrame({'lb':1,'mn':1,'ub':1,'fpr':1},index=[84])])
Yb.head()
BND=[metrics.auc(Yb.fpr, Yb.lb),metrics.auc(Yb.fpr, Yb.mn),metrics.auc(Yb.fpr, Yb.ub)]
BND
print(T, '% cnfbnd', BND[0],BND[2], ' mean:', BND[1])
# Out:
# 0.99 % cnfbnd 0.9278177349999999 0.9390688349999999  mean: 0.9334432649999999

# %%
def pickleModel(models,threshold=0.87,filename='model.pkl',verbose=True):
    '''
        save trained model set
    '''
    MODELS=[]
    for key,mds in models.items():
        if key >= threshold:
            mds_=mds
            MODELS.extend(mds_)
    if verbose:
        print("number of models (tests):", len(MODELS))
        FS=getCoverage(MODELS,verbose=True)
        print("Item Use Fraction:", FS.size/(len(MODELS)+0.0))
    dump(MODELS, filename)
    return MODELS

def loadModel(filename):
    '''
        load models
    '''
    return load(filename)

def drawTrees(model):
    '''
        draw the estimators (trees)
        in a single model
    '''
    N=len(model.estimators_)

    for count in range(N):
        estimator = model.estimators_[count]

        export_graphviz(estimator, out_file='PSYSSAOtree.dot', 
                        #feature_names = iris.feature_names,
                        #class_names = iris.target_names,
                        rounded = True, proportion = False, 
                        precision = 2, filled = True)

        from subprocess import call
        call(['dot', '-Tpng', 'PSYSSAOtree.dot', '-o', 'PSYSSAOtree'+str(count)+'.png', '-Gdpi=600'])
        from IPython.display import Image
        Image(filename = 'PSYSSAOtree'+str(count)+'.png') 
        
def getCoverage(model,verbose=True):
    '''
        return how many distinct items (questions)
        are used in the model set.
        This includes the set of questions being
        covered by all forms that may be 
        generated by the model set
    '''
    FS=[]
    for m in model:
        for count in range(len(m.estimators_)):
            clf=m.estimators_[count]
            fs=clf.tree_.feature[clf.tree_.feature>0]
            FS=np.array(list(set(np.append(FS,fs))))
    if verbose:
        print("Number of items used: ", FS.size)
    return FS

# %%
models=pickleModel(CLF,threshold=.81,filename='SCH+scffvxmodel_3_2.pkl',verbose=True)
# Out:
# number of models (tests): 1722
# Number of items used:  82
# Item Use Fraction: 0.047619047619047616

# %%
models
# Out:
# [ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
# ...
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced', criterion='gini',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=2, n_jobs=None,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False),
#  ...]

# %%
drawTrees(models[3])

# %%
getCoverage([CLFstar])
# Out:
# Number of items used:  28
# array([ 1.,  5.,  6.,  9., 11., 14., 17., 18., 20., 21., 22., 31., 37.,
#        38., 53., 54., 55., 57., 60., 64., 65., 68., 70., 73., 74., 75.,
#        77., 78.])

# %%
drawTrees(CLFstar)
