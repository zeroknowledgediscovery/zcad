# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from scipy.spatial import ConvexHull
from tqdm import tqdm
import random
plt.style.use('ggplot')
import pickle
from sklearn import tree
from sklearn.tree import export_graphviz
from joblib import dump, load
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from scipy.interpolate import interp1d
# %matplotlib inline

# %%
def getAuc(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,FPR=[],TPR=[],VERBOSE=False, USE_ONLY=None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit,class_weight='balanced'),
                RandomForestClassifier(n_estimators=n_estimators,
                                       max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                ExtraTreesClassifier(n_estimators=n_estimators,
                                     max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict_proba(X_test)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        auc=metrics.auc(fpr, tpr)
        if VERBOSE:
            print(auc)

        FPR=np.append(FPR,fpr)
        TPR=np.append(TPR,tpr)
    points=np.array([[a[0],a[1]] for a in zip(FPR,TPR)])
    hull = ConvexHull(points)
    x=np.argsort(points[hull.vertices,:][:,0])
    auc=metrics.auc(points[hull.vertices,:][x,0],points[hull.vertices,:][x,1])
    return auc,CLASSIFIERS


def saveFIG(filename='tmp.pdf',AXIS=False):
    '''
        save fig for publication
    '''
    import pylab as plt
    plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
    plt.margins(0,0)
    if not AXIS:
        plt.gca().xaxis.set_major_locator(plt.NullLocator())
        plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig(filename,dpi=300, bbox_inches = 'tight',
                pad_inches = 0,transparent=False) 
    return

# %%
df=pd.read_csv('psychoByDiag.csv',index_col=0,sep=',')

# %%
df=df[df['DX']>0]

#df=df[df.DX.between(1,2)]

X=df.iloc[:,1:].values
y=df.iloc[:,0].values.astype(str)
#y=[(x=='1')+0 for x in y]

y=[(int(x)<3)+0 for x in y ]

Xdiag=X

# %%
Xdiag.shape
# Out:
# (644, 5)

# %%
ACC=[]
CLFdiag=None
for run in tqdm(np.arange(500)):
    auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=6,n_estimators=2,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    ACC=np.append(ACC,auc)
    if auc > 0.85:
        CLFdiag=CLFS
sns.distplot(ACC)
np.median(ACC)
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 199.33it/s]
# 0.8369255543168588

# %%
df=pd.read_csv('PSYCHO.DAT',header=None,index_col=0,sep='\s+')
df=df[df[1]>0]
#df=df[df[1].between(1,2)]

X=df.loc[:,2:].values
#y=df.loc[:,1].values.astype(str)
#y=(df.loc[:,1]==1)+0
y=[(df.loc[:,1]<3)+0 for x in y ]

Xpsy=X

# %%
df=pd.read_csv('/home/ishanu/Dropbox/scratch_/Qfeatures.csv')
df=df[df.labels>0]

#df=df[df.labels.between(1,2)]

Xq=df.drop('labels',axis=1).values
#y=df.labels.values.astype(str)
X=np.c_[Xpsy,Xq]
#X=Xpsy
#X=np.c_[X,Xdiag]
#X=np.c_[Xpsy,Xdiag]
#X=X1
#X=np.c_[Xpsy,Xdiag]

# %%
y=(df.labels<3)+0

# %%
X.shape
# Out:
# (644, 83)

# %%
qACC=[]
CLF={}
for run in tqdm(np.arange(2000)):
    auc,CLFS=getAuc(X,y,test_size=0.6,max_depth=6,n_estimators=2,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    qACC=np.append(qACC,auc)
    if auc > 0.8:
        CLF[auc]=CLFS
        #print('.')
ax=sns.distplot(ACC,label='noq')
sns.distplot(qACC,ax=ax,label='Q')
ax.legend()
np.median(qACC)
CLF
# Out:
# 100%|██████████| 2000/2000 [00:11<00:00, 179.03it/s]
# {0.8698830409356725: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8214697406340057: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8617101492987483: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8812991642084562: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8955285778917207: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8692536506219578: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8820235886562418: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8185645272601794: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8584167709637047: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8186857760951866: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9096471065440779: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8905489453758787: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8655051622418879: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8188193293382634: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8112010710187428: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8678743961352657: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8775510204081634: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.877642576204523: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8356117952773698: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8712462908011869: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8513946587537092: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8383585722011898: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8525035014005602: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.809639168685452: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8188400576368875: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8551873198847263: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8512125629472569: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8858069164265129: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9226445743989604: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8069226608977826: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8423592690834071: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8483436853002071: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8086815561959655: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8689371852637159: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8473775017253278: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8048083170890189: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8176152737752161: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.872997496871089: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8400316694314583: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8505866114561766: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8251541409765039: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8552254561906198: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8657044348296375: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8903799566492414: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8351304478962449: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8470243748021525: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8445094217024041: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8344020172910663: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8809829637641968: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8118258609486679: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8605912930474333: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8321051919956733: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8732229123533471: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8622838616714698: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.894824016563147: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8612364302833779: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.848992843890803: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.851742645109992: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8312189213311233: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8970738237919165: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8718317123489537: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8949034749034749: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8128598247809762: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.876920907937403: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9005543537047052: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9232046332046332: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.842857142857143: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8991864831038798: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8986677005498379: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8847379829147011: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8556007509386733: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.889311241065627: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8589650145772594: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8535288795053537: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.895376121463078: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8684423813734159: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8442940804051915: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9278818443804034: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8427975086138352: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8338859416445623: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8673260971055088: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8555265754969688: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8125717200051001: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8314481268011528: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8377978288453405: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8234044325945675: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8601946998377501: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8172013274336284: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8780083829096809: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8143129301868239: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.85585668633235: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8111311239193084: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8422855879752432: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8603084415584416: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8665492957746479: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9402377521613833: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8424993373972964: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8668615984405459: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8542260208926875: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8231628242074928: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8415856174476863: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8736615895038455: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8925595734044326: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8203243616287095: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8385732412237417: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8624373710580607: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
# ...
#              verbose=0, warm_start=False)],
#  0.8243989603638726: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8761420571765398: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.837566765578635: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8386970172684459: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8541407867494824: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8652046783625731: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8459454290450084: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9111760883690708: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8635446685878962: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8354363456929366: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8201566951566951: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8210181179015683: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8951612903225807: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8539094650205763: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8784998526377839: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8436257619931089: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8515212399540757: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8041015107341638: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8722170686456401: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8713167912025941: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.893503761315823: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8415385634773389: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8916868545199542: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8347800159024648: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8117322291235334: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8553206997084547: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8671745505546348: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8601270957274202: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8813885884261763: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8539812999547579: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8577647823261858: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8824417919245506: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8059136420525657: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8392646625405247: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.879240412979351: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  ...}

# %%
CLFstar=CLF[np.array([k for k in CLF.keys()]).max()][0]

# %%
auc_=[]
ROC={}
fpr_ = np.linspace(0, 1, num=20, endpoint=True)
for run in np.arange(1000):
    clf=CLFstar
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    y_pred=clf.predict_proba(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
    f = interp1d(fpr, tpr)
    auc_=np.append(auc_,metrics.auc(fpr_, f(fpr_)))
    ROC[metrics.auc(fpr, tpr)]={'fpr':fpr_,'tpr':f(fpr_)}
sns.distplot(auc_)
auc_.mean()
# Out:
# 0.9498816117783402

# %%
TPR=[]
plt.figure(figsize=[6,5])
for a in ROC.keys():
    #print(a)
    #break
    plt.plot(ROC[a]['fpr'],ROC[a]['tpr'],'-k',alpha=.05)
    TPR=np.append(TPR,ROC[a]['tpr'])
TPR=TPR.reshape(int(len(TPR)/len(fpr_)),len(fpr_))
plt.plot(fpr_,np.median(TPR,axis=0),'-r')
metrics.auc(fpr_,np.median(TPR,axis=0))
#plt.gca().set_title('schizophrenia + scheff vs others')
#plt.text(.6,.65,'AUC: '+str(metrics.auc(fpr_,np.median(TPR,axis=0)))[:5],color='r')
#plt.text(.6,.65,'AUC: '+str(93.0)+'%',color='r')
#plt.text(.6,.31,'AUC: '+str(metrics.auc(fpr_,np.median(tprA,axis=0)))[:5],color='b')
#plt.text(.6,.19,'AUC: '+str(metrics.auc(fpr_,np.median(tprB,axis=0)))[:5],color='g')
#plt.gca().set_xlabel('1-specificity')
#plt.gca().set_ylabel('sensitivity')

FS=18
#plt.gca().set_title('schizophrenia or schizoaffective vs others',fontsize=18,y=1.02)
plt.text(.6,.65,'AUC: '+str(93.0)+'%',color='r',fontsize=FS)
#plt.text(.6,.25,'AUC: '+str(metrics.auc(fpr_,np.median(TPR,axis=0)))[:5],color='r')
#plt.text(.6,.31,'AUC: '+str(metrics.auc(fpr_,np.median(tprA,axis=0)))[:5],color='b')
#plt.text(.6,.19,'AUC: '+str(metrics.auc(fpr_,np.median(tprB,axis=0)))[:5],color='g')
FS=18
plt.gca().set_ylabel('sensitivity',fontsize=FS,labelpad=10,color='.5')
plt.gca().set_xlabel('1-specificity',fontsize=FS,labelpad=10,color='.5')
plt.gca().tick_params(axis='x', labelsize=FS,labelcolor='.5' )
plt.gca().tick_params(axis='y', labelsize=FS ,labelcolor='.5')



saveFIG('sczsceff.pdf',AXIS=True)

# %%
# confidence bound calculations
from scipy import interpolate
import subprocess
from sklearn import metrics

xnew = np.arange(0.01, 1, 0.01)

Y=[]
for a in ROC.keys():
    #print(a)
    #break
    x=ROC[a]['fpr']
    y=ROC[a]['tpr']
    f = interpolate.interp1d(x, y)
    ynew = f(xnew)
    Y=np.append(Y,ynew)
    #plt.plot(x, y, 'o', xnew, ynew, '-')
    #break
Y=pd.DataFrame(Y.reshape(int(len(Y)/len(xnew)),len(xnew))).sample(20).transpose()
Y.to_csv('Y.csv',index=None,header=None,sep=' ')
T=0.99

CNFBD="~/ZED/Research/data_science_/bin/cnfbd "
subprocess.call(CNFBD+" -N 5  -f Y.csv -a "+str(T)+" > Y.dat ", shell=True)
Yb=pd.read_csv('Y.dat',header=None,sep=' ',names=['lb','mn','ub'])
Yb['fpr']=xnew
Yb.head()
BND=[metrics.auc(Yb.fpr, Yb.lb),metrics.auc(Yb.fpr, Yb.mn),metrics.auc(Yb.fpr, Yb.ub)]
BND
print(T, '% cnfbnd', BND[0],BND[2], ' mean:', BND[1])
# Out:
# 0.99 % cnfbnd 0.922253265 0.9377972949999999  mean: 0.9300252649999999

# %%
def pickleModel(models,threshold=0.87,filename='model.pkl',verbose=True):
    '''
        save trained model set
    '''
    MODELS=[]
    for key,mds in models.items():
        if key >= threshold:
            mds_=mds
            MODELS.extend(mds_)
    if verbose:
        print("number of models (tests):", len(MODELS))
        FS=getCoverage(MODELS,verbose=True)
        print("Item Use Fraction:", FS.size/(len(MODELS)+0.0))
    dump(MODELS, filename)
    return MODELS

def loadModel(filename):
    '''
        load models
    '''
    return load(filename)

def drawTrees(model):
    '''
        draw the estimators (trees)
        in a single model
    '''
    N=len(model.estimators_)

    for count in range(N):
        estimator = model.estimators_[count]

        export_graphviz(estimator, out_file='PSYtree.dot', 
                        #feature_names = iris.feature_names,
                        #class_names = iris.target_names,
                        rounded = True, proportion = False, 
                        precision = 2, filled = True)

        from subprocess import call
        call(['dot', '-Tpng', 'PSYtree.dot', '-o', 'PSYtree'+str(count)+'.png', '-Gdpi=600'])
        from IPython.display import Image
        Image(filename = 'PSYtree'+str(count)+'.png') 
        
def getCoverage(model,verbose=True):
    '''
        return how many distinct items (questions)
        are used in the model set.
        This includes the set of questions being
        covered by all forms that may be 
        generated by the model set
    '''
    FS=[]
    for m in model:
        for count in range(len(m.estimators_)):
            clf=m.estimators_[count]
            fs=clf.tree_.feature[clf.tree_.feature>0]
            FS=np.array(list(set(np.append(FS,fs))))
    if verbose:
        print("Number of items used: ", FS.size)
    return FS

# %%
models=pickleModel(CLF,threshold=.81,filename='SCH+scffvxmodel_3_2.pkl',verbose=True)
# Out:
# number of models (tests): 1756
# Number of items used:  77
# Item Use Fraction: 0.043849658314350795

# %%
models
# Out:
# [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)]

# %%
drawTrees(models[3])
