# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from scipy.spatial import ConvexHull
from tqdm import tqdm
import random
plt.style.use('ggplot')
import pickle
from sklearn import tree
from sklearn.tree import export_graphviz
from joblib import dump, load
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from scipy.interpolate import interp1d
# %matplotlib inline

# %%
def getAuc(X,y,test_size=0.25,max_depth=None,n_estimators=100,
           minsplit=4,FPR=[],TPR=[],VERBOSE=False, USE_ONLY=None):
    '''
        get AUC given training data X, with target labels y
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    CLASSIFIERS=[DecisionTreeClassifier(max_depth=max_depth, min_samples_split=minsplit,class_weight='balanced'),
                RandomForestClassifier(n_estimators=n_estimators,
                                       max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                ExtraTreesClassifier(n_estimators=n_estimators,
                                     max_depth=max_depth,min_samples_split=minsplit,class_weight='balanced'),
                AdaBoostClassifier(n_estimators=n_estimators),
                GradientBoostingClassifier(n_estimators=n_estimators,max_depth=max_depth),
                svm.SVC(kernel='rbf',gamma='scale',class_weight='balanced',probability=True)]

    if USE_ONLY is not None:
        if isinstance(USE_ONLY, (list,)):
            CLASSIFIERS=[CLASSIFIERS[i] for i in USE_ONLY]
        if isinstance(USE_ONLY, (int,)):
            CLASSIFIERS=CLASSIFIERS[USE_ONLY]

    for clf in CLASSIFIERS:
        clf.fit(X_train,y_train)
        y_pred=clf.predict_proba(X_test)
        fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
        auc=metrics.auc(fpr, tpr)
        if VERBOSE:
            print(auc)

        FPR=np.append(FPR,fpr)
        TPR=np.append(TPR,tpr)
    points=np.array([[a[0],a[1]] for a in zip(FPR,TPR)])
    hull = ConvexHull(points)
    x=np.argsort(points[hull.vertices,:][:,0])
    auc=metrics.auc(points[hull.vertices,:][x,0],points[hull.vertices,:][x,1])
    return auc,CLASSIFIERS


def saveFIG(filename='tmp.pdf',AXIS=False):
    '''
        save fig for publication
    '''
    import pylab as plt
    plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
    plt.margins(0,0)
    if not AXIS:
        plt.gca().xaxis.set_major_locator(plt.NullLocator())
        plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig(filename,dpi=300, bbox_inches = 'tight',
                pad_inches = 0,transparent=False) 
    return

# %%
df=pd.read_csv('psychoByDiag.csv',index_col=0,sep=',')

# %%
df=df[df['DX']>0]

#df=df[df.DX.between(1,2)]

X=df.iloc[:,1:].values
y=df.iloc[:,0].values.astype(str)
#y=[(x=='1')+0 for x in y]

y=[(int(x)<3)+0 for x in y ]

Xdiag=X

# %%
Xdiag.shape
# Out:
# (644, 5)

# %%
ACC=[]
CLFdiag=None
for run in tqdm(np.arange(500)):
    auc,CLFS=getAuc(X,y,test_size=0.2,max_depth=6,n_estimators=2,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    ACC=np.append(ACC,auc)
    if auc > 0.85:
        CLFdiag=CLFS
sns.distplot(ACC)
np.median(ACC)
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 198.42it/s]
# 0.8452778355400412

# %%
df=pd.read_csv('PSYCHO.DAT',header=None,index_col=0,sep='\s+')
df=df[df[1]>0]
#df=df[df[1].between(1,2)]

X=df.loc[:,2:].values
#y=df.loc[:,1].values.astype(str)
#y=(df.loc[:,1]==1)+0
y=[(df.loc[:,1]<3)+0 for x in y ]

Xpsy=X

# %%
df=pd.read_csv('/home/ishanu/Dropbox/scratch_/Qfeatures.csv')
df=df[df.labels>0]

#df=df[df.labels.between(1,2)]

Xq=df.drop('labels',axis=1).values
#y=df.labels.values.astype(str)
X=np.c_[Xpsy,Xq]
#X=Xpsy
#X=np.c_[X,Xdiag]
#X=np.c_[Xpsy,Xdiag]
#X=X1
#X=np.c_[Xpsy,Xdiag]

# %%
y=(df.labels<3)+0

# %%
X.shape
# Out:
# (644, 83)

# %%
qACC=[]
CLF={}
for run in tqdm(np.arange(2000)):
    auc,CLFS=getAuc(X,y,test_size=0.6,max_depth=6,n_estimators=2,
               minsplit=2,VERBOSE=False, USE_ONLY=[2])
    qACC=np.append(qACC,auc)
    if auc > 0.8:
        CLF[auc]=CLFS
        #print('.')
ax=sns.distplot(ACC,label='noq')
sns.distplot(qACC,ax=ax,label='Q')
ax.legend()
np.median(qACC)
CLF
# Out:
# 100%|██████████| 2000/2000 [00:11<00:00, 174.40it/s]
# {0.888299440023578: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8187874537804412: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8450368313005676: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8303961652333286: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8578890489913544: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8408212560386473: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8735815376769095: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8206821026282853: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8476055194805194: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8632030827474311: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8834678695789806: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8548877771768524: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8868585732165205: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8768552875695732: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8609385783298826: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.895031055900621: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8950487012987014: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8557312252964427: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8576673164392461: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8689020771513353: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8749385447394298: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8901736019082958: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8503442560244805: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8520893371757925: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8336648983200707: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8440922190201728: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8540286244367876: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9018398420978428: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9008177075990415: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9039226080042406: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.871684350132626: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.864373325814183: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8745677233429394: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8564764737696051: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8273619788346296: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8310266406757634: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9093477144324602: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8633976833976834: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9063489418430261: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8564481268011528: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8794346978557503: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8017763992668828: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8955256570713392: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8138086403392526: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8535979326795653: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8463068181818182: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8736737400530503: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8587536023054755: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8743479486817989: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8206334481844686: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8905467138225759: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8394409937888199: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8722001178897731: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9015578739602426: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8657898614795166: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8836191281246226: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8548568778160615: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8545808966861599: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8216551529677147: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.831351689612015: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8612763656030287: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8900000000000001: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8245759342698118: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8826722967878149: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.866341780376868: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8649793692897142: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8415444015444015: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8651483781918565: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8600890207715133: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8953844192273365: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.872083386459263: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8404121388815267: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8160818713450292: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8857152514872906: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8037740660461559: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8163605051664753: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8291703507220749: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9052956465237167: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8240941049215792: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9071783756215733: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8306916426512969: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8907943389009307: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8390489913544669: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8387163561076605: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8070048309178744: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8444429421308816: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8787784679089028: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8389965574397551: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8042083744536866: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8109636184857424: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8485230547550433: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8154589371980676: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8532432432432433: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8141399416909622: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8319164265129682: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8647342995169083: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8658753709198813: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8392834374601555: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8454908058409951: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8529580517659059: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8696602283941914: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8811679204386078: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9085576259489303: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8473032069970845: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8664092664092664: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8083850931677019: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
# ...
#              verbose=0, warm_start=False)],
#  0.8165224445646295: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8225504322766571: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8358178053830227: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8582052728041731: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8786874593892138: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8302743175192155: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8239820565907522: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8787463976945245: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8878109789075175: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8348462761728067: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.878824192866206: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.857826843937955: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8726445743989603: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9001564455569462: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8209551656920078: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8223248272945157: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8525096525096525: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8176041103299081: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8168969406457072: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8985162180814356: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8342430149447694: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.9067390384886507: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8139715212181025: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8131815044858524: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8897334293948127: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8620022123893806: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8466138328530259: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8403002960665445: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8126640926640927: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8555694618272841: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8730394808004327: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8428300094966763: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.821808510638298: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8502923976608188: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  0.8543478260869565: [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#              criterion='gini', max_depth=6, max_features='auto',
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#              verbose=0, warm_start=False)],
#  ...}

# %%
CLFstar=CLF[np.array([k for k in CLF.keys()]).max()][0]

# %%
auc_=[]
ROC={}
fpr_ = np.linspace(0, 1, num=20, endpoint=True)
for run in np.arange(1000):
    clf=CLFstar
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    y_pred=clf.predict_proba(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
    f = interp1d(fpr, tpr)
    auc_=np.append(auc_,metrics.auc(fpr_, f(fpr_)))
    ROC[metrics.auc(fpr, tpr)]={'fpr':fpr_,'tpr':f(fpr_)}
sns.distplot(auc_)
auc_.mean()
# Out:
# 0.9451686007139886

# %%
TPR=[]
for a in ROC.keys():
    #print(a)
    #break
    plt.plot(ROC[a]['fpr'],ROC[a]['tpr'],'-k',alpha=.05)
    TPR=np.append(TPR,ROC[a]['tpr'])
TPR=TPR.reshape(int(len(TPR)/len(fpr_)),len(fpr_))
plt.plot(fpr_,np.median(TPR,axis=0),'-r')
metrics.auc(fpr_,np.median(TPR,axis=0))
plt.gca().set_title('schizophrenia + scheff vs others')
plt.text(.6,.65,'AUC: '+str(metrics.auc(fpr_,np.median(TPR,axis=0)))[:5],color='r')
#plt.text(.6,.31,'AUC: '+str(metrics.auc(fpr_,np.median(tprA,axis=0)))[:5],color='b')
#plt.text(.6,.19,'AUC: '+str(metrics.auc(fpr_,np.median(tprB,axis=0)))[:5],color='g')
plt.gca().set_xlabel('1-specificity')
plt.gca().set_ylabel('sensitivity')
saveFIG('sczsceff.pdf',AXIS=True)

# %%
# confidence bound calculations
from scipy import interpolate
import subprocess
from sklearn import metrics

xnew = np.arange(0.01, 1, 0.01)

Y=[]
for a in ROC.keys():
    #print(a)
    #break
    x=ROC[a]['fpr']
    y=ROC[a]['tpr']
    f = interpolate.interp1d(x, y)
    ynew = f(xnew)
    Y=np.append(Y,ynew)
    #plt.plot(x, y, 'o', xnew, ynew, '-')
    #break
Y=pd.DataFrame(Y.reshape(int(len(Y)/len(xnew)),len(xnew))).sample(20).transpose()
Y.to_csv('Y.csv',index=None,header=None,sep=' ')
T=0.99

CNFBD="~/ZED/Research/data_science_/bin/cnfbd "
subprocess.call(CNFBD+" -N 5  -f Y.csv -a "+str(T)+" > Y.dat ", shell=True)
Yb=pd.read_csv('Y.dat',header=None,sep=' ',names=['lb','mn','ub'])
Yb['fpr']=xnew
Yb.head()
BND=[metrics.auc(Yb.fpr, Yb.lb),metrics.auc(Yb.fpr, Yb.mn),metrics.auc(Yb.fpr, Yb.ub)]
BND
print(T, '% cnfbnd', BND[0],BND[2], ' mean:', BND[1])
# Out:
# 0.99 % cnfbnd 0.922253265 0.9377972949999999  mean: 0.9300252649999999

# %%
def pickleModel(models,threshold=0.87,filename='model.pkl',verbose=True):
    '''
        save trained model set
    '''
    MODELS=[]
    for key,mds in models.items():
        if key >= threshold:
            mds_=mds
            MODELS.extend(mds_)
    if verbose:
        print("number of models (tests):", len(MODELS))
        FS=getCoverage(MODELS,verbose=True)
        print("Item Use Fraction:", FS.size/(len(MODELS)+0.0))
    dump(MODELS, filename)
    return MODELS

def loadModel(filename):
    '''
        load models
    '''
    return load(filename)

def drawTrees(model):
    '''
        draw the estimators (trees)
        in a single model
    '''
    N=len(model.estimators_)

    for count in range(N):
        estimator = model.estimators_[count]

        export_graphviz(estimator, out_file='PSYtree.dot', 
                        #feature_names = iris.feature_names,
                        #class_names = iris.target_names,
                        rounded = True, proportion = False, 
                        precision = 2, filled = True)

        from subprocess import call
        call(['dot', '-Tpng', 'PSYtree.dot', '-o', 'PSYtree'+str(count)+'.png', '-Gdpi=600'])
        from IPython.display import Image
        Image(filename = 'PSYtree'+str(count)+'.png') 
        
def getCoverage(model,verbose=True):
    '''
        return how many distinct items (questions)
        are used in the model set.
        This includes the set of questions being
        covered by all forms that may be 
        generated by the model set
    '''
    FS=[]
    for m in model:
        for count in range(len(m.estimators_)):
            clf=m.estimators_[count]
            fs=clf.tree_.feature[clf.tree_.feature>0]
            FS=np.array(list(set(np.append(FS,fs))))
    if verbose:
        print("Number of items used: ", FS.size)
    return FS

# %%
models=pickleModel(CLF,threshold=.81,filename='SCH+scffvxmodel_3_2.pkl',verbose=True)
# Out:
# number of models (tests): 1756
# Number of items used:  77
# Item Use Fraction: 0.043849658314350795

# %%
models
# Out:
# [ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, class_weight='balanced',
#             criterion='gini', max_depth=3, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2, n_jobs=None, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)]

# %%
drawTrees(models[3])
